# %%
from mmnrm.utils import set_random_seed, load_neural_model, load_model, flat_list
from mmnrm.dataset import TestCollectionV2, sentence_splitter_builderV2, TrainSnippetsCollectionV2
from mmnrm.evaluation import BioASQ_JavaEvaluator

from collections import defaultdict
import os
import pickle
import numpy as np
import sys
import math
import time
import tensorflow as tf
from nltk.tokenize.punkt import PunktSentenceTokenizer
from utils import *

import nltk

# %%
# some queries to use as an example
def build_data_generators(tokenizer, use_joint=True, queries_sw=None, docs_sw=None):
    
    punkt_sent_tokenizer = PunktSentenceTokenizer().span_tokenize

    def maybe_tokenize(documents):
        if "tokens" not in documents:
            if use_joint:
                split = []
                spans = []
                for _itter, position in enumerate(punkt_sent_tokenizer(documents["text"])):
                    start, end = position
                    _text = documents["text"][start:end]

                    is_title = True
                    if _itter>0: # fix the start and end position for the abstract
                        
                        if _itter == 1: # auxiliar correction to set the abstract at 0 index
                            diff = (len(documents["title"])-1)+(start-(len(documents["title"])-1))
                            
                        start = start-diff
                        end = end-diff
                        is_title = False
                    
                    split.append(_text)
                    spans.append({"start":start,
                                  "end":end-1,
                                  "text":_text,
                                  "is_title":is_title,
                                  "snippet_id":documents["id"]+"_"+str(_itter),
                                  "doc_id":documents["id"]})
                documents["spans"] = spans
            else:
                split = nltk.sent_tokenize(documents["text"])
                
            documents["tokens"] = tokenizer.texts_to_sequences(split)
            if docs_sw is not None:
                for tokenized_sentence in documents["tokens"]:
                    tokenized_sentence = [token for token in tokenized_sentence if token not in docs_sw]

    def test_generator(data_generator):
        for _id, query, docs in data_generator:
            tokenized_queries = []
            for i in range(len(_id)):
                # tokenization
                tokenized_query = tokenizer.texts_to_sequences([query[i]])[0]

                if queries_sw is not None:
                    tokenized_query = [token for token in tokenized_query if token not in queries_sw] 
                
                tokenized_queries.append(tokenized_query)
                    
        
                for doc in docs[i]:
                    maybe_tokenize(doc)
                                                 
            yield _id, tokenized_queries, docs
            
    return test_generator

def get_test_generator_for_model(model, use_joint):

    if "model" in model.savable_config:
        cfg = model.savable_config["model"]
    
    test_gen = build_data_generators(model.tokenizer, use_joint)
    
    pad_tokens = lambda x, max_len, dtype='int32': tf.keras.preprocessing.sequence.pad_sequences(x, 
                                                                                           maxlen=max_len,
                                                                                           dtype=dtype, 
                                                                                           padding='post', 
                                                                                           truncating='post', 
                                                                                           value=0)

    pad_sentences = lambda x, max_lim, dtype='int32': x[:max_lim] + [[]]*(max_lim-len(x))
    
    def maybe_padding(document):
        if isinstance(document["tokens"], list):
            #overflow prevention
            bounded_doc_passage = min(cfg["max_passages"],len(document["tokens"]))
            document["sentences_mask"] = [True] * bounded_doc_passage + [False] * (cfg["max_passages"]-bounded_doc_passage)
            document["tokens"] = pad_tokens(pad_sentences(document["tokens"], cfg["max_passages"]), cfg["max_p_terms"])
            document["spans"] = document["spans"][:cfg["max_passages"]]
            
    def test_generator(data_generator):
        
        for ids, query, docs in test_gen(data_generator):
            
            docs_spans = []
            docs_ids = []
            docs_array = []
            docs_mask_array = []
            query_array = []
            query_ids = []
            
            for i in range(len(ids)):
                
                for doc in docs[i]:
                    # pad docs, use cache here
                    maybe_padding(doc)
                    docs_array.append(doc["tokens"])
                    docs_mask_array.append(doc["sentences_mask"])
                    docs_ids.append(doc["id"])
                    docs_spans.append(doc["spans"])
                    
                query_tokens = pad_tokens([query[i]], cfg["max_q_terms"])[0]
                query_tokens = [query_tokens] * len(docs[i])
                query_array.append(query_tokens)
                    
                query_ids.append([ids[i]]*len(docs[i]))
            
            #print(np.array(docs_mask_array))
            
            yield flat_list(query_ids), [np.array(flat_list(query_array)), np.array(docs_array), np.array(docs_mask_array)], docs_ids, docs_spans
            
    return test_generator

queries = load_queries("BioASQ-task9bPhaseA-testset3", maps=[("body","query")])

# %%
ranking_model = load_model("trained_models/honest-morning-60_val_collection0_doc_map@10")
# Out:
# DEBUG created tokenizer bioasq_9b_RegexTokenizer
# False False
# [LOAD FROM CACHE] Load embedding matrix from /backup/BioASQ-9b/embeddings/WORD2VEC_embedding_bioasq_9b_gensim_iter_15_freq0_200_Regex_word2vec_bioasq_9b_RegexTokenizer
# Using einsum for mask bq,bps->bpqs and with embedding dim bqe,bpse->bpqs
# [EMBEDDING MATRIX SHAPE] (5322623, 200)

# %%
test_input_generator = get_test_generator_for_model(ranking_model, use_joint=True)

# %%
def rank(model, t_collection):

    generator_Y = t_collection.generator()
                
    q_scores = defaultdict(list)

    for query_id, Y, docs_ids, docs_spans in generator_Y:
        s_time = time.time()
        
        scores = model.predict(Y)
        doc_scores = scores[0][:,0].tolist()
        snippets_scores = scores[1].tolist()
        
        for i in range(len(doc_scores)):
            
            for j in range(len(docs_spans[i])):
                docs_spans[i][j]["score"] = snippets_scores[i][j][0]
            
            #q_scores[query_id].extend(list(zip(docs_ids,scores)))
            q_scores[query_id[i]].append({"id":docs_ids[i],
                                          "score":doc_scores[i],
                                          "snippets":docs_spans[i]})
        
        print("\rEvaluation {} | time {}".format(len(q_scores), time.time()-s_time), end="\r")

    # sort the rankings
    for query_id in q_scores.keys():
        q_scores[query_id].sort(key=lambda x:-x["score"])
        q_scores[query_id] = q_scores[query_id]
    
    return q_scores

def rerank_run(baseline_file, top_k):
    run = load_document_run(baseline_file, dict_format=True)

    tCollection = TestCollectionV2(queries, run)\
                      .batch_size(top_k)\
                      .set_transform_inputs_fn(test_input_generator)
    
    results = rank(ranking_model, tCollection)
    
    return results ## update the run results

# %%
rerank = rerank_run(os.path.join("runs/rnd3", "bm25-baseline.run"), 100)
# Out:
# Evaluation 100 | time 0.31703734397888184

# %%
def snippetRank_bySort(results):
    snippets_results = {}
    for q in results.keys():
        snippets_list = flat_list([x["snippets"] for x in results[q]])
        snippets_results[q] = sorted(snippets_list, key=lambda x: -x["score"])
        
    return snippets_results

def snippetRank_byThreshold(results, threshold):
    snippets_results = {}
    # this will follow the document order first
    for q in results.keys():
        snippets_results[q] = [y for y in flat_list([x["snippets"] for x in results[q]]) if y["score"] >= threshold]
        
    return snippets_results

def snippetRank_byThreshold_and_TopK(results, threshold, topK):
    snippets_results = {}
    # this will follow the document order first
    for q in results.keys():
        snippets_results[q] = [y for y in flat_list([x["snippets"] for x in results[q][:topK]]) if y["score"] >= threshold]
        
    return snippets_results

# %%
evaluator = BioASQ_JavaEvaluator("BioASQ-task9bPhaseB-testset3", 
                                 "/home/tiagoalmeida/BioASQ-9b/BioASQEvaluator/BioASQEvaluation.jar",
                                 write_as_bioasq)

snippets = snippetRank_bySort(rerank)

run = create_document_run(queries, rerank, snippets)

evaluator.evaluate(run)
# Out:
# Remove /tmp/tmprt2bttm0
# {'doc_p@10': 0.11499999999999995,
#  'doc_r@10': 0.4654141414141413,
#  'doc_f1@10': 0.16651067224828836,
#  'doc_map@10': 0.35071740362811793,
#  'doc_gmap@10': 0.0069504130851034225,
#  'snippet_p@10': 0.08505336416681805,
#  'snippet_r@10': 0.17641778927184135,
#  'snippet_f1@10': 0.10271486432212351,
#  'snippet_map@10': 0.22603522246306731,
#  'snippet_gmap@10': 0.0011442407919515175}

# %%
run[0]
# Out:
# {'id': '6057c78994d57fd879000034',
#  'type': 'factoid',
#  'query': 'Which protein is involved in the organization and regulation of pluripotency-associated three-dimensional enhancer networks?',
#  'documents': [{'id': '31548608',
#    'score': 15.519436836242676,
#    'snippets': [{'start': 0,
#      'end': 114,
#      'text': 'KLF4 is involved in the organization and regulation of pluripotency-associated three-dimensional enhancer networks.',
#      'is_title': True,
#      'doc_id': '31548608',
#      'score': 0.7081087231636047},
#     {'start': 0,
#      'end': 259,
#      'text': 'Cell fate transitions are accompanied by global transcriptional, epigenetic and topological changes driven by transcription factors, as is exemplified by reprogramming somatic cells to pluripotent stem cells through the expression of OCT4, KLF4, SOX2 and cMYC.',
#      'is_title': False,
#      'doc_id': '31548608',
#      'score': 0.15228056907653809},
#     {'start': 261,
#      'end': 390,
#      'text': 'How transcription factors orchestrate the complex molecular changes around their target gene loci remains incompletely understood.',
#      'is_title': False,
#      'doc_id': '31548608',
#      'score': 0.05758190155029297},
#     {'start': 392,
#      'end': 669,
#      'text': 'Here, using KLF4 as a paradigm, we provide a transcription-factor-centric view of chromatin reorganization and its association with three-dimensional enhancer rewiring and transcriptional changes during the reprogramming of mouse embryonic fibroblasts to pluripotent stem cells.',
#      'is_title': False,
#      'doc_id': '31548608',
#      'score': 0.39797115325927734},
#     {'start': 671,
#      'end': 967,
#      'text': 'Inducible depletion of KLF factors in PSCs caused a genome-wide decrease in enhancer connectivity, whereas disruption of individual KLF4 binding sites within pluripotent-stem-cell-specific enhancers was sufficient to impair enhancer-promoter contacts and reduce the expression of associated genes.',
#      'is_title': False,
#      'doc_id': '31548608',
#      'score': 0.25990283489227295},
#     {'start': 969,
#      'end': 1185,
#      'text': 'Our study provides an integrative view of the complex activities of a lineage-specifying transcription factor and offers novel insights into the nature of the molecular events that follow transcription factor binding.',
#      'is_title': False,
#      'doc_id': '31548608',
#      'score': 0.05906429886817932}]},
#   {'id': '23199754',
#    'score': 11.437383651733398,
#    'snippets': [{'start': 0,
#      'end': 60,
#      'text': 'Pluripotency in 3D: genome organization in pluripotent cells.',
#      'is_title': True,
#      'doc_id': '23199754',
#      'score': 0.40288621187210083},
#     {'start': 0,
#      'end': 134,
#      'text': 'Cells face the challenge of storing two meters of DNA in the three-dimensional (3D) space of the nucleus that spans only a few microns.',
#      'is_title': False,
#      'doc_id': '23199754',
#      'score': 0.13167187571525574},
#     {'start': 136,
#      'end': 408,
#      'text': 'The nuclear organization that is required to overcome this challenge must allow for the accessibility of the gene regulatory machinery to the DNA and, in the case of embryonic stem cells (ESCs), for the transcriptional and epigenetic changes that accompany differentiation.',
#      'is_title': False,
#      'doc_id': '23199754',
#      'score': 0.2666993737220764},
#     {'start': 410,
#      'end': 532,
#      'text': 'Recent technological advances have allowed for the mapping of genome organization at an unprecedented resolution and scale.',
#      'is_title': False,
#      'doc_id': '23199754',
#      'score': 0.11587250232696533},
#     {'start': 534,
#      'end': 713,
#      'text': 'These breakthroughs have led to a deluge of new data, and a sophisticated understanding of the relationship between gene regulation and 3D genome organization is beginning to form.',
#      'is_title': False,
#      'doc_id': '23199754',
#      'score': 0.1825897991657257},
#     {'start': 715,
#      'end': 1076,
#      'text': 'In this review we summarize some of the recent findings illuminating the 3D structure of the eukaryotic genome, as well as the relationship between genome topology and function from the level of whole chromosomes to enhancer-promoter loops with a focus on features affecting genome organization in ESCs and changes in nuclear organization during differentiation.',
#      'is_title': False,
#      'doc_id': '23199754',
#      'score': 0.49772197008132935}]},
#   {'id': '32553182',
#    'score': 11.311578750610352,
#    'snippets': [{'start': 0,
#      'end': 108,
#      'text': 'Genomic Rewiring of SOX2 Chromatin Interaction Network during Differentiation of ESCs to Postmitotic Neurons.',
#      'is_title': True,
#      'doc_id': '32553182',
#      'score': 0.29788559675216675},
#     {'start': 0,
#      'end': 128,
#      'text': 'Cellular differentiation requires dramatic changes in chromatin organization, transcriptional regulation, and protein production.',
#      'is_title': False,
#      'doc_id': '32553182',
#      'score': 0.14769163727760315},
#     {'start': 130,
#      'end': 467,
#      'text': 'To understand the regulatory connections between these processes, we generated proteomic, transcriptomic, and chromatin accessibility data during differentiation of mouse embryonic stem cells (ESCs) into postmitotic neurons and found extensive associations between different molecular layers within and across differentiation time points.',
#      'is_title': False,
#      'doc_id': '32553182',
#      'score': 0.2127506136894226},
#     {'start': 469,
#      'end': 690,
#      'text': 'We observed that SOX2, as a regulator of pluripotency and neuronal genes, redistributes from pluripotency enhancers to neuronal promoters during differentiation, likely driven by changes in its protein interaction network.',
#      'is_title': False,
#      'doc_id': '32553182',
#      'score': 0.5031372904777527},
#     {'start': 692,
#      'end': 912,
#      'text': 'We identified ATRX as a major SOX2 partner in neurons, whose co-localization correlated with an increase in active enhancer marks and increased expression of nearby genes, which we experimentally confirmed for three loci.',
#      'is_title': False,
#      'doc_id': '32553182',
#      'score': 0.15763896703720093},
#     {'start': 914,
#      'end': 1144,
#      'text': 'Collectively, our data provide key insights into the regulatory transformation of SOX2 during neuronal differentiation, and we highlight the significance of multi-omic approaches in understanding gene regulation in complex systems.',
#      'is_title': False,
#      'doc_id': '32553182',
#      'score': 0.10985422134399414}]},
#   {'id': '27471257',
#    'score': 11.235023498535156,
#    'snippets': [{'start': 0,
#      'end': 128,
#      'text': 'Sall4 controls differentiation of pluripotent cells independently of the Nucleosome Remodelling and Deacetylation (NuRD) complex.',
#      'is_title': True,
#      'doc_id': '27471257',
#      'score': 0.24639463424682617},
#     {'start': 0,
#      'end': 116,
#      'text': 'Sall4 is an essential transcription factor for early mammalian development and is frequently overexpressed in cancer.',
#      'is_title': False,
#      'doc_id': '27471257',
#      'score': 0.0972265899181366},
#     {'start': 118,
#      'end': 275,
#      'text': 'Although it is reported to play an important role in embryonic stem cell (ESC) self-renewal, whether it is an essential pluripotency factor has been disputed.',
#      'is_title': False,
#      'doc_id': '27471257',
#      'score': 0.21590715646743774},
#     {'start': 277,
#      'end': 343,
#      'text': 'Here, we show that Sall4 is dispensable for mouse ESC pluripotency.',
#      'is_title': False,
#      'doc_id': '27471257',
#      'score': 0.23391544818878174},
#     {'start': 345,
#      'end': 545,
#      'text': 'Sall4 is an enhancer-binding protein that prevents precocious activation of the neural gene expression programme in ESCs but is not required for maintenance of the pluripotency gene regulatory network.',
#      'is_title': False,
#      'doc_id': '27471257',
#      'score': 0.4841834604740143},
#     {'start': 547,
#      'end': 824,
#      'text': 'Although a proportion of Sall4 protein physically associates with the Nucleosome Remodelling and Deacetylase (NuRD) complex, Sall4 neither recruits NuRD to chromatin nor influences transcription via NuRD; rather, free Sall4 protein regulates transcription independently of NuRD.',
#      'is_title': False,
#      'doc_id': '27471257',
#      'score': 0.10221952199935913},
#     {'start': 826,
#      'end': 1033,
#      'text': 'We propose a model whereby enhancer binding by Sall4 and other pluripotency-associated transcription factors is responsible for maintaining the balance between transcriptional programmes in pluripotent cells.',
#      'is_title': False,
#      'doc_id': '27471257',
#      'score': 0.44995638728141785}]},
#   {'id': '29372665',
#    'score': 10.940218925476074,
#    'snippets': [{'start': 0,
#      'end': 188,
#      'text': 'DNA methylation of the Oct4A enhancers in embryonal carcinoma cells after etoposide treatment is associated with alternative splicing and altered pluripotency in reversibly senescent cells.',
#      'is_title': True,
#      'doc_id': '29372665',
#      'score': 0.36239680647850037},
#     {'start': 0,
#      'end': 140,
#      'text': 'The epigenetic mechanisms underlying chemoresistance in cancer cells resulting from drug-induced reversible senescence are poorly understood.',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.09827521443367004},
#     {'start': 142,
#      'end': 394,
#      'text': 'Chemoresistant ESC-like embryonal carcinoma PA1 cells treated with etoposide (ETO) were previously found to undergo prolonged G2 arrest with transient p53-dependent upregulation of opposing fate regulators, p21CIP1 (senescence) and OCT4A (self-renewal).',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.09764865040779114},
#     {'start': 396,
#      'end': 554,
#      'text': 'Here we report on the analysis of the DNA methylation state of the distal enhancer (DE) and proximal enhancer (PE) of the Oct4A gene during this dual response.',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.15672793984413147},
#     {'start': 556,
#      'end': 696,
#      'text': 'When compared to non-treated controls the methylation level increased from 1.3% to 12.5% and from 3% to 19.4%, in the DE and PE respectively.',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.09951764345169067},
#     {'start': 698,
#      'end': 804,
#      'text': 'It included CpG and non-CpG methylation, which was not chaotic but presented two patterns in each enhancer.',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.16123738884925842},
#     {'start': 806,
#      'end': 1071,
#      'text': 'Discorrelating with methylation of enhancers, the transcription of Oct4A increased, however, a strong expression of the splicing form Oct4B was also induced, along with down-regulation of the Oct4A partners of in the pluripotency/self-renewal network Sox2 and Lin28.',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.4819476008415222},
#     {'start': 1073,
#      'end': 1154,
#      'text': 'WB demonstrated disjoining of the OCT4A protein from the chromatin-bound fraction.',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.10324835777282715},
#     {'start': 1156,
#      'end': 1285,
#      'text': 'In survival clones, methylation of the DE was considerably erased, while some remnant of methylation of the PE was still observed.',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.09949445724487305},
#     {'start': 1287,
#      'end': 1473,
#      'text': 'The alternative splicing for Oct4B was reduced, Oct4A level insignificantly decreased, while the expression of Sox2 and Lin28 recovered, all three became proportionally above the control.',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.10344123840332031},
#     {'start': 1475,
#      'end': 1739,
#      'text': 'These findings indicate the involvement of the transient patterned methylation of the Oct4A enhancers and alternative splicing in the adaptive regulation of cell fate choice during the p53-dependant dual state of reversible senescence in ESC-like cancer stem cells.',
#      'is_title': False,
#      'doc_id': '29372665',
#      'score': 0.18598923087120056}]},
#   {'id': '26765775',
#    'score': 10.674539566040039,
#    'snippets': [{'start': 0,
#      'end': 74,
#      'text': 'Role of ALKBH1 in the Core Transcriptional Network of Embryonic Stem Cells.',
#      'is_title': True,
#      'doc_id': '26765775',
#      'score': 0.1245814859867096},
#     {'start': 0,
#      'end': 171,
#      'text': 'BACKGROUND/AIMS\nALKBH1, an AlkB homologue in the 2-oxoglutarate and Fe2+ dependent hydroxylase family, is a histone dioxygenase that removes methyl groups from histone H2A.',
#      'is_title': False,
#      'doc_id': '26765775',
#      'score': 0.10476219654083252},
#     {'start': 173,
#      'end': 282,
#      'text': 'Studies of transgenic mice lacking Alkbh1 reveal that most Alkbh1-/- embryos die during embryonic development.',
#      'is_title': False,
#      'doc_id': '26765775',
#      'score': 0.09883207082748413},
#     {'start': 284,
#      'end': 537,
#      'text': 'Embryonic stem cells (ESCs) derived from these mice have prolonged expression of pluripotency markers and delayed induction of genes involved in neural differentiation, indicating that ALKBH1 is involved in regulation of pluripotency and differentiation.',
#      'is_title': False,
#      'doc_id': '26765775',
#      'score': 0.3430096507072449},
#     {'start': 539,
#      'end': 624,
#      'text': 'The aim of this study was to further investigate the role ALKBH1 in early development.',
#      'is_title': False,
#      'doc_id': '26765775',
#      'score': 0.10196158289909363},
#     {'start': 628,
#      'end': 839,
#      'text': 'METHODS\nDouble-filter methods for nitrocellulose-filter binding, dot blot, enzyme-linked immunosorbent assay (ELISA), immonocytochemistry, cell culture and differentiation of mouse ESCs, Co-IP and miRNA analysis.',
#      'is_title': False,
#      'doc_id': '26765775',
#      'score': 0.2339635193347931},
#     {'start': 843,
#      'end': 1032,
#      'text': 'RESULTS\nWe found that SOX2 and NANOG bind the ALKBH1 promoter, and we identified protein-protein interactions between ALKBH1 and these core transcription factors of the pluripotency network.',
#      'is_title': False,
#      'doc_id': '26765775',
#      'score': 0.4504778981208801},
#     {'start': 1034,
#      'end': 1201,
#      'text': 'Furthermore, lack of ALKBH1 affected the expression of developmentally important miRNAs, which are involved in the regulation of NANOG, SOX2 and neural differentiation.',
#      'is_title': False,
#      'doc_id': '26765775',
#      'score': 0.31529873609542847},
#     {'start': 1205,
#      'end': 1382,
#      'text': 'CONCLUSION\nOur results suggest that ALKBH1 interacts with the core transcriptional pluripotency network of ESCs and is involved in regulation of pluripotency and differentiation.',
#      'is_title': False,
#      'doc_id': '26765775',
#      'score': 0.4017235338687897}]},
#   {'id': '24777452',
#    'score': 10.655994415283203,
#    'snippets': [{'start': 0,
#      'end': 128,
#      'text': 'Deep transcriptome profiling of mammalian stem cells supports a regulatory role for retrotransposons in pluripotency maintenance.',
#      'is_title': True,
#      'doc_id': '24777452',
#      'score': 0.24576252698898315},
#     {'start': 0,
#      'end': 190,
#      'text': 'The importance of microRNAs and long noncoding RNAs in the regulation of pluripotency has been documented; however, the noncoding components of stem cell gene networks remain largely unknown.',
#      'is_title': False,
#      'doc_id': '24777452',
#      'score': 0.38223984837532043},
#     {'start': 192,
#      'end': 340,
#      'text': 'Here we investigate the role of noncoding RNAs in the pluripotent state, with particular emphasis on nuclear and retrotransposon-derived transcripts.',
#      'is_title': False,
#      'doc_id': '24777452',
#      'score': 0.25615397095680237},
#     {'start': 342,
#      'end': 527,
#      'text': 'We have performed deep profiling of the nuclear and cytoplasmic transcriptomes of human and mouse stem cells, identifying a class of previously undetected stem cell-specific transcripts.',
#      'is_title': False,
#      'doc_id': '24777452',
#      'score': 0.10201424360275269},
#     {'start': 529,
#      'end': 668,
#      'text': 'We show that long terminal repeat (LTR)-derived transcripts contribute extensively to the complexity of the stem cell nuclear transcriptome.',
#      'is_title': False,
#      'doc_id': '24777452',
#      'score': 0.10034841299057007},
#     {'start': 670,
#      'end': 800,
#      'text': 'Some LTR-derived transcripts are associated with enhancer regions and are likely to be involved in the maintenance of pluripotency.',
#      'is_title': False,
#      'doc_id': '24777452',
#      'score': 0.45888859033584595}]},
#   {'id': '31221664',
#    'score': 10.504301071166992,
#    'snippets': [{'start': 0,
#      'end': 121,
#      'text': 'KLF4 protein stability regulated by interaction with pluripotency transcription factors overrides transcriptional control.',
#      'is_title': True,
#      'doc_id': '31221664',
#      'score': 0.2726683020591736},
#     {'start': 0,
#      'end': 113,
#      'text': 'Embryonic stem (ES) cells are regulated by a network of transcription factors that maintain the pluripotent state.',
#      'is_title': False,
#      'doc_id': '31221664',
#      'score': 0.2761201858520508},
#     {'start': 115,
#      'end': 218,
#      'text': 'Differentiation relies on down-regulation of pluripotency transcription factors disrupting this network.',
#      'is_title': False,
#      'doc_id': '31221664',
#      'score': 0.3756549060344696},
#     {'start': 220,
#      'end': 597,
#      'text': 'While investigating transcriptional regulation of the pluripotency transcription factor Kruppel-like factor 4 (Klf4), we observed that homozygous deletion of distal enhancers caused a 17-fold decrease in Klf4 transcript but surprisingly decreased protein levels by less than twofold, indicating that posttranscriptional control of KLF4 protein overrides transcriptional control.',
#      'is_title': False,
#      'doc_id': '31221664',
#      'score': 0.4509628713130951},
#     {'start': 599,
#      'end': 698,
#      'text': 'The lack of sensitivity of KLF4 to transcription is due to high protein stability (half-life >24 h).',
#      'is_title': False,
#      'doc_id': '31221664',
#      'score': 0.11053293943405151},
#     {'start': 700,
#      'end': 1020,
#      'text': 'This stability is context-dependent and is disrupted during differentiation, as evidenced by a shift to a half-life of <2 h. KLF4 protein stability is maintained through interaction with other pluripotency transcription factors (NANOG, SOX2, and STAT3) that together facilitate association of KLF4 with RNA polymerase II.',
#      'is_title': False,
#      'doc_id': '31221664',
#      'score': 0.268865168094635},
#     {'start': 1022,
#      'end': 1131,
#      'text': 'In addition, the KLF4 DNA-binding and transactivation domains are required for optimal KLF4 protein stability.',
#      'is_title': False,
#      'doc_id': '31221664',
#      'score': 0.11121487617492676},
#     {'start': 1133,
#      'end': 1310,
#      'text': 'Posttranslational modification of KLF4 destabilizes the protein as cells exit the pluripotent state, and mutations that prevent this destabilization also prevent differentiation.',
#      'is_title': False,
#      'doc_id': '31221664',
#      'score': 0.2682322859764099},
#     {'start': 1312,
#      'end': 1569,
#      'text': 'These data indicate that the core pluripotency transcription factors are integrated by posttranslational mechanisms to maintain the pluripotent state and identify mutations that increase KLF4 protein stability while maintaining transcription factor function.',
#      'is_title': False,
#      'doc_id': '31221664',
#      'score': 0.23399245738983154}]},
#   {'id': '30266927',
#    'score': 10.469011306762695,
#    'snippets': [{'start': 0,
#      'end': 171,
#      'text': 'Three-Dimensional Retinal Organoids Facilitate the Investigation of Retinal Ganglion Cell Development, Organization and Neurite Outgrowth from Human Pluripotent Stem Cells.',
#      'is_title': True,
#      'doc_id': '30266927',
#      'score': 0.46932312846183777},
#     {'start': 0,
#      'end': 235,
#      'text': 'Retinal organoids are three-dimensional structures derived from human pluripotent stem cells (hPSCs) which recapitulate the spatial and temporal differentiation of the retina, serving as effective in vitro models of retinal development.',
#      'is_title': False,
#      'doc_id': '30266927',
#      'score': 0.31366026401519775},
#     {'start': 237,
#      'end': 376,
#      'text': 'However, a lack of emphasis has been placed upon the development and organization of retinal ganglion cells (RGCs) within retinal organoids.',
#      'is_title': False,
#      'doc_id': '30266927',
#      'score': 0.13068628311157227},
#     {'start': 378,
#      'end': 623,
#      'text': 'Thus, initial efforts were made to characterize RGC differentiation throughout early stages of organoid development, with a clearly defined RGC layer developing in a temporally-appropriate manner expressing a complement of RGC-associated markers.',
#      'is_title': False,
#      'doc_id': '30266927',
#      'score': 0.10587576031684875},
#     {'start': 625,
#      'end': 804,
#      'text': 'Beyond studies of RGC development, retinal organoids may also prove useful for cellular replacement in which extensive axonal outgrowth is necessary to reach post-synaptic targets.',
#      'is_title': False,
#      'doc_id': '30266927',
#      'score': 0.10580062866210938},
#     {'start': 806,
#      'end': 973,
#      'text': 'Organoid-derived RGCs could help to elucidate factors promoting axonal outgrowth, thereby identifying approaches to circumvent a formidable obstacle to RGC replacement.',
#      'is_title': False,
#      'doc_id': '30266927',
#      'score': 0.10016009211540222},
#     {'start': 975,
#      'end': 1137,
#      'text': 'As such, additional efforts demonstrated significant enhancement of neurite outgrowth through modulation of both substrate composition and growth factor signaling.',
#      'is_title': False,
#      'doc_id': '30266927',
#      'score': 0.10293316841125488},
#     {'start': 1139,
#      'end': 1280,
#      'text': 'Additionally, organoid-derived RGCs exhibited diverse phenotypes, extending elaborate growth cones and expressing numerous guidance receptors.',
#      'is_title': False,
#      'doc_id': '30266927',
#      'score': 0.10172152519226074},
#     {'start': 1282,
#      'end': 1540,
#      'text': 'Collectively, these results establish retinal organoids as a valuable tool for studies of RGC development, and demonstrate the utility of organoid-derived RGCs as an effective platform to study factors influencing neurite outgrowth from organoid-derived RGCs.',
#      'is_title': False,
#      'doc_id': '30266927',
#      'score': 0.1039593517780304}]},
#   {'id': '30863449',
#    'score': 10.369046211242676,
#    'snippets': [{'start': 0,
#      'end': 137,
#      'text': 'The Role of RNA Polymerase II Contiguity and Long-Range Interactions in the Regulation of Gene Expression in Human Pluripotent Stem Cells.',
#      'is_title': True,
#      'doc_id': '30863449',
#      'score': 0.30869418382644653},
#     {'start': 0,
#      'end': 189,
#      'text': 'The eukaryotic nucleus is a highly complex structure that carries out multiple functions primarily needed for gene expression, and among them, transcription seems to be the most fundamental.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.10597193241119385},
#     {'start': 191,
#      'end': 412,
#      'text': 'Diverse approaches have demonstrated that transcription takes place at discrete sites known as transcription factories, wherein RNA polymerase II (RNAP II) is attached to the factory and immobilized while transcribing DNA.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.10560482740402222},
#     {'start': 414,
#      'end': 598,
#      'text': 'It has been proposed that transcription factories promote chromatin loop formation, creating long-range interactions in which relatively distant genes can be transcribed simultaneously.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.10410195589065552},
#     {'start': 600,
#      'end': 909,
#      'text': 'In this study, we examined long-range interactions between the POU5F1 gene and genes previously identified as being POU5F1 enhancer-interacting, namely, CDYL, TLE2, RARG, and MSX1 (all involved in transcriptional regulation), in human pluripotent stem cells (hPSCs) and their early differentiated counterparts.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.4484449028968811},
#     {'start': 911,
#      'end': 1038,
#      'text': 'As a control gene, RUNX1 was used, which is expressed during hematopoietic differentiation and not associated with pluripotency.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.26265716552734375},
#     {'start': 1040,
#      'end': 1313,
#      'text': 'To reveal how these long-range interactions between POU5F1 and the selected genes change with the onset of differentiation and upon RNAP II inhibition, we performed three-dimensional fluorescence in situ hybridization (3D-FISH) followed by computational simulation analysis.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.14999845623970032},
#     {'start': 1315,
#      'end': 1519,
#      'text': 'Our analysis showed that the numbers of long-range interactions between specific genes decrease during differentiation, suggesting that the transcription of monitored genes is associated with pluripotency.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.25966376066207886},
#     {'start': 1521,
#      'end': 1640,
#      'text': 'In addition, we showed that upon inhibition of RNAP II, long-range associations do not disintegrate and remain constant.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.10640057921409607},
#     {'start': 1642,
#      'end': 1833,
#      'text': 'We also analyzed the distance distributions of these genes in the context of their positions in the nucleus and revealed that they tend to have similar patterns resembling normal distribution.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.10745862126350403},
#     {'start': 1835,
#      'end': 1945,
#      'text': 'Furthermore, we compared data created in vitro and in silico to assess the biological relevance of our results.',
#      'is_title': False,
#      'doc_id': '30863449',
#      'score': 0.10668230056762695}]},
#   {'id': '32562758',
#    'score': 10.34384536743164,
#    'snippets': [{'start': 0,
#      'end': 49,
#      'text': 'DNA methylation and the core pluripotency network.',
#      'is_title': True,
#      'doc_id': '32562758',
#      'score': 0.28680557012557983},
#     {'start': 0,
#      'end': 87,
#      'text': 'From the onset of fertilization, the genome undergoes cell division and differentiation.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.10561397671699524},
#     {'start': 89,
#      'end': 227,
#      'text': 'All of these developmental transitions and differentiation processes include cell-specific signatures and gradual changes of the epigenome.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.10598498582839966},
#     {'start': 229,
#      'end': 380,
#      'text': 'Understanding what keeps stem cells in the pluripotent state and what leads to differentiation are fascinating and biomedically highly important issues.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.25422459840774536},
#     {'start': 382,
#      'end': 490,
#      'text': 'Numerous studies have identified genes, proteins, microRNAs and small molecules that exert essential effects.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.10321137309074402},
#     {'start': 492,
#      'end': 611,
#      'text': 'Notably, there exists a core pluripotency network that consists of several transcription factors and accessory proteins.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.2775859832763672},
#     {'start': 613,
#      'end': 719,
#      'text': 'Three eminent transcription factors, OCT4, SOX2 and NANOG, serve as hubs in this core pluripotency network.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.32389211654663086},
#     {'start': 721,
#      'end': 924,
#      'text': 'They bind to the enhancer regions of their target genes and modulate, among others, the expression levels of genes that are associated with Gene Ontology terms related to differentiation and self-renewal.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.17643365263938904},
#     {'start': 926,
#      'end': 1027,
#      'text': 'Also, much has been learned about the epigenetic rewiring processes during these changes of cell fate.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.10387203097343445},
#     {'start': 1029,
#      'end': 1106,
#      'text': 'For example, DNA methylation dynamics is pivotal during embryonic development.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.10323336720466614},
#     {'start': 1108,
#      'end': 1449,
#      'text': 'The main goal of this review is to highlight an intricate interplay of (a) DNA methyltransferases controlling the expression levels of core pluripotency factors by modulation of the DNA methylation levels in their enhancer regions, and of (b) the core pluripotency factors controlling the transcriptional regulation of DNA methyltransferases.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.4437042474746704},
#     {'start': 1451,
#      'end': 1601,
#      'text': 'We discuss these processes both at the global level and in atomistic detail based on information from structural studies and from computer simulations.',
#      'is_title': False,
#      'doc_id': '32562758',
#      'score': 0.10622531175613403}]},
#   {'id': '29514091',
#    'score': 10.248522758483887,
#    'snippets': [{'start': 0,
#      'end': 130,
#      'text': 'Long-Range Enhancer Interactions Are Prevalent in Mouse Embryonic Stem Cells and Are Reorganized upon Pluripotent State Transition.',
#      'is_title': True,
#      'doc_id': '29514091',
#      'score': 0.3677775263786316},
#     {'start': 0,
#      'end': 148,
#      'text': 'Transcriptional enhancers, including super-enhancers (SEs), form physical interactions with promoters to regulate cell-type-specific gene expression.',
#      'is_title': False,
#      'doc_id': '29514091',
#      'score': 0.16429558396339417},
#     {'start': 150,
#      'end': 332,
#      'text': 'SEs are characterized by high transcription factor occupancy and large domains of active chromatin, and they are commonly assigned to target promoters using computational predictions.',
#      'is_title': False,
#      'doc_id': '29514091',
#      'score': 0.10517621040344238},
#     {'start': 334,
#      'end': 481,
#      'text': 'How promoter-SE interactions change upon cell state transitions, and whether transcription factors maintain SE interactions, have not been reported.',
#      'is_title': False,
#      'doc_id': '29514091',
#      'score': 0.16661447286605835},
#     {'start': 483,
#      'end': 600,
#      'text': 'Here, we used promoter-capture Hi-C to identify promoters that interact with SEs in mouse embryonic stem cells (ESCs).',
#      'is_title': False,
#      'doc_id': '29514091',
#      'score': 0.32012271881103516},
#     {'start': 602,
#      'end': 779,
#      'text': 'We found that SEs form complex, spatial networks in which individual SEs contact multiple promoters, and a rewiring of promoter-SE interactions occurs between pluripotent states.',
#      'is_title': False,
#      'doc_id': '29514091',
#      'score': 0.4290946424007416},
#     {'start': 781,
#      'end': 922,
#      'text': 'We also show that long-range promoter-SE interactions are more prevalent in ESCs than in epiblast stem cells (EpiSCs) or Nanog-deficient ESCs.',
#      'is_title': False,
#      'doc_id': '29514091',
#      'score': 0.3685828745365143},
#     {'start': 924,
#      'end': 1132,
#      'text': 'We conclude that SEs form cell-type-specific interaction networks that are partly dependent on core transcription factors, thereby providing insights into the gene regulatory organization of pluripotent cells.',
#      'is_title': False,
#      'doc_id': '29514091',
#      'score': 0.3570590019226074}]},
#   {'id': '28147265',
#    'score': 10.137882232666016,
#    'snippets': [{'start': 0,
#      'end': 81,
#      'text': 'Gender Differences in Global but Not Targeted Demethylation in iPSC Reprogramming.',
#      'is_title': True,
#      'doc_id': '28147265',
#      'score': 0.10552334785461426},
#     {'start': 0,
#      'end': 188,
#      'text': 'Global DNA demethylation is an integral part of reprogramming processes in\xa0vivo and in\xa0vitro, but whether it occurs in the derivation of induced pluripotent stem cells (iPSCs) is not known.',
#      'is_title': False,
#      'doc_id': '28147265',
#      'score': 0.2805059552192688},
#     {'start': 190,
#      'end': 345,
#      'text': 'Here, we show that iPSC reprogramming involves both global and targeted demethylation, which are separable mechanistically and by their biological outcomes.',
#      'is_title': False,
#      'doc_id': '28147265',
#      'score': 0.10664835572242737},
#     {'start': 347,
#      'end': 483,
#      'text': 'Cells at intermediate-late stages of reprogramming undergo transient genome-wide demethylation, which is more pronounced in female cells.',
#      'is_title': False,
#      'doc_id': '28147265',
#      'score': 0.11006316542625427},
#     {'start': 485,
#      'end': 692,
#      'text': 'Global demethylation requires activation-induced cytidine deaminase (AID)-mediated downregulation of UHRF1 protein, and abolishing demethylation leaves thousands of hypermethylated regions in the iPSC genome.',
#      'is_title': False,
#      'doc_id': '28147265',
#      'score': 0.1180504858493805},
#     {'start': 694,
#      'end': 916,
#      'text': 'Independently of AID and global demethylation, regulatory regions, particularly ESC enhancers and super-enhancers, are specifically targeted for hypomethylation in association with transcription of the pluripotency network.',
#      'is_title': False,
#      'doc_id': '28147265',
#      'score': 0.4567837417125702},
#     {'start': 918,
#      'end': 1145,
#      'text': 'Our results show that global and targeted DNA demethylation are conserved and\xa0distinct reprogramming processes, presumably because of their respective roles in epigenetic memory erasure and in the establishment of cell identity.',
#      'is_title': False,
#      'doc_id': '28147265',
#      'score': 0.11022317409515381}]},
#   {'id': '29180618',
#    'score': 10.04347038269043,
#    'snippets': [{'start': 0,
#      'end': 73,
#      'text': 'A transcribed enhancer dictates mesendoderm specification in pluripotency.',
#      'is_title': True,
#      'doc_id': '29180618',
#      'score': 0.40541893243789673},
#     {'start': 0,
#      'end': 108,
#      'text': 'Enhancers and long noncoding RNAs (lncRNAs) are key determinants of lineage specification during development.',
#      'is_title': False,
#      'doc_id': '29180618',
#      'score': 0.1812184453010559},
#     {'start': 110,
#      'end': 240,
#      'text': 'Here, we evaluate remodeling of the enhancer landscape and modulation of the lncRNA transcriptome during mesendoderm specification.',
#      'is_title': False,
#      'doc_id': '29180618',
#      'score': 0.18145865201950073},
#     {'start': 242,
#      'end': 485,
#      'text': 'We sort mesendodermal progenitors from differentiating embryonic stem cells (ESCs) according to Eomes expression, and find that enhancer usage is coordinated with mesendoderm-specific expression of key lineage-determining transcription factors.',
#      'is_title': False,
#      'doc_id': '29180618',
#      'score': 0.3563392162322998},
#     {'start': 487,
#      'end': 556,
#      'text': 'Many of these enhancers are associated with the expression of lncRNAs.',
#      'is_title': False,
#      'doc_id': '29180618',
#      'score': 0.18528583645820618},
#     {'start': 558,
#      'end': 763,
#      'text': 'Examination of ESC-specific enhancers interacting in three-dimensional space with mesendoderm-specifying transcription factor loci identifies MesEndoderm Transcriptional Enhancer Organizing Region (Meteor).',
#      'is_title': False,
#      'doc_id': '29180618',
#      'score': 0.26574966311454773},
#     {'start': 765,
#      'end': 985,
#      'text': 'Genetic and epigenetic manipulation of the Meteor enhancer reveal its indispensable role during mesendoderm specification and subsequent cardiogenic differentiation via transcription-independent and -dependent mechanisms.',
#      'is_title': False,
#      'doc_id': '29180618',
#      'score': 0.1795782446861267},
#     {'start': 987,
#      'end': 1084,
#      'text': 'Interestingly, Meteor-deleted ESCs are epigenetically redirected towards neuroectodermal lineages.',
#      'is_title': False,
#      'doc_id': '29180618',
#      'score': 0.2370816469192505},
#     {'start': 1086,
#      'end': 1288,
#      'text': 'Loci, topologically associating a transcribed enhancer and its cognate protein coding gene, appear to represent therefore a class of genomic elements controlling developmental competence in pluripotency.',
#      'is_title': False,
#      'doc_id': '29180618',
#      'score': 0.4206128716468811}]},
#   {'id': '23549118',
#    'score': 9.938804626464844,
#    'snippets': [{'start': 0,
#      'end': 75,
#      'text': 'The interactomes of POU5F1 and SOX2 enhancers in human embryonic stem cells.',
#      'is_title': True,
#      'doc_id': '23549118',
#      'score': 0.18976709246635437},
#     {'start': 0,
#      'end': 152,
#      'text': 'The genes POU5F1 and SOX2 are critical for pluripotency and reprogramming, yet the chromosomal organization around these genes remains poorly understood.',
#      'is_title': False,
#      'doc_id': '23549118',
#      'score': 0.31996476650238037},
#     {'start': 154,
#      'end': 308,
#      'text': 'We assayed long-range chromosomal interactions on putative enhancers of POU5F1 and SOX2 genes in human embryonic stem cells (hESCs) using 4C-Seq technique.',
#      'is_title': False,
#      'doc_id': '23549118',
#      'score': 0.39866986870765686},
#     {'start': 310,
#      'end': 413,
#      'text': 'We discovered that their frequent interacting regions mainly overlap with early DNA replication domains.',
#      'is_title': False,
#      'doc_id': '23549118',
#      'score': 0.10612431168556213},
#     {'start': 415,
#      'end': 520,
#      'text': 'The interactomes are associated with active histone marks and enriched with 5-hydroxymethylcytosine sites.',
#      'is_title': False,
#      'doc_id': '23549118',
#      'score': 0.11248305439949036},
#     {'start': 522,
#      'end': 586,
#      'text': 'In hESCs, genes within the interactomes have elevated expression.',
#      'is_title': False,
#      'doc_id': '23549118',
#      'score': 0.25428152084350586},
#     {'start': 588,
#      'end': 675,
#      'text': 'Additionally, some genes associated with the POU5F1 enhancer contribute to pluripotency.',
#      'is_title': False,
#      'doc_id': '23549118',
#      'score': 0.41570454835891724},
#     {'start': 677,
#      'end': 816,
#      'text': 'Binding sites for multiple DNA binding proteins, including ATF3, CTCF, GABPA, JUND, NANOG, RAD21 and YY1, are enriched in both interactomes.',
#      'is_title': False,
#      'doc_id': '23549118',
#      'score': 0.25257909297943115},
#     {'start': 818,
#      'end': 958,
#      'text': 'The RARG locus, frequently interacting with the POU5F1 locus, has abundant RAD21 binding sites co-localized with other protein binding sites.',
#      'is_title': False,
#      'doc_id': '23549118',
#      'score': 0.11369895935058594},
#     {'start': 960,
#      'end': 1075,
#      'text': 'Thus the interactomes of these two pluripotency genes could be an important part of the regulatory network in hESCs.',
#      'is_title': False,
#      'doc_id': '23549118',
#      'score': 0.3358808755874634}]},
#   {'id': '24648406',
#    'score': 9.893735885620117,
#    'snippets': [{'start': 0,
#      'end': 121,
#      'text': 'Coactivators p300 and CBP maintain the identity of mouse embryonic stem cells by mediating long-range chromatin structure.',
#      'is_title': True,
#      'doc_id': '24648406',
#      'score': 0.11095663905143738},
#     {'start': 0,
#      'end': 189,
#      'text': 'Master transcription factors Oct4, Sox2, and Nanog are required to maintain the pluripotency and self-renewal of embryonic stem cells (ESCs) by regulating a specific transcriptional network.',
#      'is_title': False,
#      'doc_id': '24648406',
#      'score': 0.3523593842983246},
#     {'start': 191,
#      'end': 440,
#      'text': 'A few other transcription factors have been shown to be important in ESCs by interacting with these master transcription factors; however, little is known about the transcriptional mechanisms regulated by coregulators (coactivators and corepressors).',
#      'is_title': False,
#      'doc_id': '24648406',
#      'score': 0.25966501235961914},
#     {'start': 442,
#      'end': 565,
#      'text': 'In this study, we examined the function of two highly homologous coactivators, p300 and CREB-binding protein (CBP), in ESCs.',
#      'is_title': False,
#      'doc_id': '24648406',
#      'score': 0.3012901842594147},
#     {'start': 567,
#      'end': 673,
#      'text': 'We find that these two coactivators play redundant roles in maintaining the undifferentiated state of ESCs.',
#      'is_title': False,
#      'doc_id': '24648406',
#      'score': 0.2795216143131256},
#     {'start': 675,
#      'end': 882,
#      'text': 'They are recruited by Nanog through physical interaction to Nanog binding loci, mediating the formation of long-range chromatin looping structures, which is essential to maintain ESC-specific gene expression.',
#      'is_title': False,
#      'doc_id': '24648406',
#      'score': 0.24124464392662048},
#     {'start': 884,
#      'end': 1219,
#      'text': 'Further functional studies reveal that the p300/CBP binding looping fragments contain enhancer activities, suggesting that the formation of p300/CBP-mediated looping structures may recruit distal enhancers to create a concentration of factors for the transcription activation of genes that are involved in self-renewal and pluripotency.',
#      'is_title': False,
#      'doc_id': '24648406',
#      'score': 0.4191829264163971},
#     {'start': 1221,
#      'end': 1485,
#      'text': 'Overall, these results provide a total new insight into the transcriptional regulation mechanism of coactivators p300 and CBP in ESCs, which is important in maintaining self-renewal and pluripotency, by mediating the formation of higher order chromosome structures.',
#      'is_title': False,
#      'doc_id': '24648406',
#      'score': 0.2935965359210968}]},
#   {'id': '29042476',
#    'score': 9.866009712219238,
#    'snippets': [{'start': 0,
#      'end': 92,
#      'text': 'The three-dimensional genome: regulating gene expression during pluripotency and development.',
#      'is_title': True,
#      'doc_id': '29042476',
#      'score': 0.4218951165676117},
#     {'start': 0,
#      'end': 234,
#      'text': 'The precise expression of genes in time and space during embryogenesis is largely influenced by communication between enhancers and promoters, which is propagated and governed by the physical proximity of these elements in the nucleus.',
#      'is_title': False,
#      'doc_id': '29042476',
#      'score': 0.18712130188941956},
#     {'start': 236,
#      'end': 412,
#      'text': 'Here, we review how chromatin domains organize the genome by guiding enhancers to their target genes thereby preventing non-specific interactions with other neighboring regions.',
#      'is_title': False,
#      'doc_id': '29042476',
#      'score': 0.16716381907463074},
#     {'start': 414,
#      'end': 610,
#      'text': 'We also discuss the dynamics of chromatin interactions between enhancers and promoters, as well as the consequent changes in gene expression, that occur in pluripotent cells and during development.',
#      'is_title': False,
#      'doc_id': '29042476',
#      'score': 0.3728809356689453},
#     {'start': 612,
#      'end': 875,
#      'text': 'Finally, we evaluate how genomic changes such as deletions, inversions and duplications affect 3D chromatin configuration overall and lead to ectopic enhancer-promoter contacts, and thus gene misexpression, which can contribute to abnormal development and disease.',
#      'is_title': False,
#      'doc_id': '29042476',
#      'score': 0.22391435503959656}]},
#   {'id': '28622076',
#    'score': 9.783202171325684,
#    'snippets': [{'start': 0,
#      'end': 110,
#      'text': 'Human Induced Pluripotent Stem Cell-Derived Endothelial Cells for Three-Dimensional Microphysiological Systems.',
#      'is_title': True,
#      'doc_id': '28622076',
#      'score': 0.36644959449768066},
#     {'start': 0,
#      'end': 165,
#      'text': 'Microphysiological systems (MPS), or "organ-on-a-chip" platforms, aim to recapitulate in vivo physiology using small-scale in vitro tissue models of human physiology.',
#      'is_title': False,
#      'doc_id': '28622076',
#      'score': 0.11068680882453918},
#     {'start': 167,
#      'end': 314,
#      'text': 'While significant efforts have been made to create vascularized tissues, most reports utilize primary endothelial cells that hinder reproducibility.',
#      'is_title': False,
#      'doc_id': '28622076',
#      'score': 0.10793313384056091},
#     {'start': 316,
#      'end': 483,
#      'text': 'In this study, we report the use of human induced pluripotent stem cell-derived endothelial cells (iPS-ECs) in developing three-dimensional (3D) microvascular networks.',
#      'is_title': False,
#      'doc_id': '28622076',
#      'score': 0.4245969355106354},
#     {'start': 485,
#      'end': 610,
#      'text': 'We established a CDH5-mCherry reporter iPS cell line, which expresses the vascular endothelial (VE)-cadherin fused to mCherry.',
#      'is_title': False,
#      'doc_id': '28622076',
#      'score': 0.1105991005897522},
#     {'start': 612,
#      'end': 896,
#      'text': 'The iPS-ECs demonstrate physiological functions characteristic of primary endothelial cells in a series of in vitro assays, including permeability, response to shear stress, and the expression of endothelial markers (CD31, von Willibrand factor, and endothelial nitric oxide synthase).',
#      'is_title': False,
#      'doc_id': '28622076',
#      'score': 0.1143372654914856},
#     {'start': 898,
#      'end': 1018,
#      'text': 'The iPS-ECs form stable, perfusable microvessels over the course of 14 days when cultured within 3D microfluidic devices.',
#      'is_title': False,
#      'doc_id': '28622076',
#      'score': 0.14495491981506348},
#     {'start': 1020,
#      'end': 1125,
#      'text': 'We also demonstrate that inhibition of TGF-β signaling improves vascular network formation by the iPS-ECs.',
#      'is_title': False,
#      'doc_id': '28622076',
#      'score': 0.12957125902175903},
#     {'start': 1127,
#      'end': 1304,
#      'text': 'We conclude that iPS-ECs can be a source of endothelial cells in MPS providing opportunities for human disease modeling and improving the reproducibility of 3D vascular networks.',
#      'is_title': False,
#      'doc_id': '28622076',
#      'score': 0.17117729783058167}]},
#   {'id': '31315906',
#    'score': 9.766156196594238,
#    'snippets': [{'start': 0,
#      'end': 149,
#      'text': 'Profiling the long noncoding RNA interaction network in the regulatory elements of target genes by chromatin in situ reverse transcription sequencing.',
#      'is_title': True,
#      'doc_id': '31315906',
#      'score': 0.13434267044067383},
#     {'start': 0,
#      'end': 134,
#      'text': 'Long noncoding RNAs (lncRNAs) can regulate the activity of target genes by participating in the organization of chromatin architecture.',
#      'is_title': False,
#      'doc_id': '31315906',
#      'score': 0.1428370177745819},
#     {'start': 136,
#      'end': 399,
# ...
#    'score': 0.19083353877067566},
#   {'start': 0,
#    'end': 181,
#    'text': 'The kallikrein-kinin and renin-angiotensin (KKS-RAS) systems represent two highly regulated proteolytic systems that are involved in several physiological and pathological processes.',
#    'is_title': False,
#    'doc_id': '20180650',
#    'score': 0.1764903962612152},
#   {'start': 183,
#    'end': 438,
#    'text': 'Although their protein-protein interactions can be studied using experimental approaches, it is difficult to differentiate between direct physical interactions and functional associations, which do not involve direct atomic contacts between macromolecules.',
#    'is_title': False,
#    'doc_id': '20180650',
#    'score': 0.17073673009872437},
#   {'start': 440,
#    'end': 541,
#    'text': 'This information can be obtained from an atomic-resolution characterization of the protein interfaces.',
#    'is_title': False,
#    'doc_id': '20180650',
#    'score': 0.1675952672958374},
#   {'start': 543,
#    'end': 655,
#    'text': 'As a result of this, various three-dimensional-based protein-protein interaction databases have become available.',
#    'is_title': False,
#    'doc_id': '20180650',
#    'score': 0.2343921959400177},
#   {'start': 657,
#    'end': 824,
#    'text': 'To gain insight into the multilayered interaction of the KKS-RAS systems, we present a protein network that is built up on three-dimensional domain-domain interactions.',
#    'is_title': False,
#    'doc_id': '20180650',
#    'score': 0.27577322721481323},
#   {'start': 826,
#    'end': 1092,
#    'text': 'The essential domains that link these systems are as follows: Cystatin, Peptidase_C1, Thyroglobulin_1, Insulin, CIMR (Cation-independent mannose-6-phosphate receptor repeat), fn2 (Fibronectin type II domain), fn1 (Fibronectin type I domain), EGF, Trypsin, and Serpin.',
#    'is_title': False,
#    'doc_id': '20180650',
#    'score': 0.15941724181175232},
#   {'start': 1094,
#    'end': 1191,
#    'text': 'We found that the CIMR domain is located at the core of the network, thus connecting both systems.',
#    'is_title': False,
#    'doc_id': '20180650',
#    'score': 0.1862839162349701},
#   {'start': 1193,
#    'end': 1348,
#    'text': 'From the latter, all domain interactors up to level 4 were retrieved, thus displaying a more comprehensive representation of the KKS-RAS structural network.',
#    'is_title': False,
#    'doc_id': '20180650',
#    'score': 0.1840573251247406},
#   {'start': 0,
#    'end': 163,
#    'text': 'Ep-CAM transfection in thymic epithelial cell lines triggers the formation of dynamic actin-rich protrusions involved in the organization of epithelial cell layers.',
#    'is_title': True,
#    'doc_id': '11702195',
#    'score': 0.21225932240486145},
#   {'start': 0,
#    'end': 117,
#    'text': 'Thymic epithelium is organized in a highly connected three-dimensional network through which thymocytes differentiate.',
#    'is_title': False,
#    'doc_id': '11702195',
#    'score': 0.2675233483314514},
#   {'start': 119,
#    'end': 190,
#    'text': 'The molecular mechanisms underlying this organization are still unknown.',
#    'is_title': False,
#    'doc_id': '11702195',
#    'score': 0.19785204529762268},
#   {'start': 192,
#    'end': 347,
#    'text': 'In thymic medulla, a major site of tolerance induction, the development of the epithelial cell net is tightly regulated by the needs of thymocyte selection.',
#    'is_title': False,
#    'doc_id': '11702195',
#    'score': 0.16782167553901672},
#   {'start': 349,
#    'end': 426,
#    'text': 'These reticulated epithelial cells express high levels of the Ep-CAM molecule.',
#    'is_title': False,
#    'doc_id': '11702195',
#    'score': 0.16200625896453857},
#   {'start': 428,
#    'end': 689,
#    'text': 'Using different thymic epithelial cell lines as a model system, we found that transfection of Ep-CAM enhances cell growth and leads to a rapid reorganization of the actin cytoskeleton by inducing the formation of numerous stress fibers and long cell protrusions.',
#    'is_title': False,
#    'doc_id': '11702195',
#    'score': 0.1645474135875702},
#   {'start': 691,
#    'end': 837,
#    'text': 'Finally, the crosslinking of the extracellular domain of a chimeric CD25ec/Ep-CAMic molecule is sufficient to trigger the formation of protrusions.',
#    'is_title': False,
#    'doc_id': '11702195',
#    'score': 0.16455599665641785},
#   {'start': 839,
#    'end': 1036,
#    'text': 'These results suggest that expression of Ep-CAM might balance the organizing capacity of cadherin molecules and may be participating in the formation of a dynamic stromal cell network in the thymus.',
#    'is_title': False,
#    'doc_id': '11702195',
#    'score': 0.19614019989967346},
#   {'start': 0,
#    'end': 61,
#    'text': 'Organization of the cytokeratin network in an epithelial cell.',
#    'is_title': True,
#    'doc_id': '12850452',
#    'score': 0.2511327862739563},
#   {'start': 0,
#    'end': 89,
#    'text': 'The cytoskeleton is a dynamic three-dimensional structure mainly located in the cytoplasm.',
#    'is_title': False,
#    'doc_id': '12850452',
#    'score': 0.24609526991844177},
#   {'start': 91,
#    'end': 201,
#    'text': 'It is involved in many cell functions such as mechanical signal transduction and maintenance of cell integrity.',
#    'is_title': False,
#    'doc_id': '12850452',
#    'score': 0.18173441290855408},
#   {'start': 203,
#    'end': 353,
#    'text': 'Among the three cytoskeletal components, intermediate filaments (the cytokeratin in epithelial cells) are the best candidates for this mechanical role.',
#    'is_title': False,
#    'doc_id': '12850452',
#    'score': 0.1731824278831482},
#   {'start': 355,
#    'end': 539,
#    'text': 'A model of the establishment of the cytokeratin network of an epithelial cell is proposed to study the dependence of its structural organization on extracellular mechanical environment.',
#    'is_title': False,
#    'doc_id': '12850452',
#    'score': 0.2371448278427124},
#   {'start': 541,
#    'end': 667,
#    'text': 'To implicitly describe the latter and its effects on the intracellular domain, we use mechanically regulated protein synthesis.',
#    'is_title': False,
#    'doc_id': '12850452',
#    'score': 0.17581528425216675},
#   {'start': 669,
#    'end': 889,
#    'text': 'Our model is a hybrid of a partial differential equation of parabolic type, governing the evolution of the concentration of cytokeratin, and a set of stochastic differential equations describing the dynamics of filaments.',
#    'is_title': False,
#    'doc_id': '12850452',
#    'score': 0.17147886753082275},
#   {'start': 891,
#    'end': 1086,
#    'text': 'Each filament is described by a stochastic differential equation that reflects both the local interactions with the environment and the non-local interactions via the past history of the filament.',
#    'is_title': False,
#    'doc_id': '12850452',
#    'score': 0.17153769731521606},
#   {'start': 1088,
#    'end': 1164,
#    'text': 'A three-dimensional simulation model is derived from this mathematical model.',
#    'is_title': False,
#    'doc_id': '12850452',
#    'score': 0.23270553350448608},
#   {'start': 1166,
#    'end': 1340,
#    'text': 'This simulation model is then used to obtain examples of cytokeratin network architectures under given mechanical conditions, and to study the influence of several parameters.',
#    'is_title': False,
#    'doc_id': '12850452',
#    'score': 0.20032727718353271},
#   {'start': 0,
#    'end': 103,
#    'text': 'Making connections: insulators organize eukaryotic chromosomes into independent cis-regulatory networks.',
#    'is_title': True,
#    'doc_id': '24277632',
#    'score': 0.1947794258594513},
#   {'start': 0,
#    'end': 204,
#    'text': 'Insulators play a central role in subdividing the chromosome into a series of discrete topologically independent domains and in ensuring that enhancers and silencers contact their appropriate target genes.',
#    'is_title': False,
#    'doc_id': '24277632',
#    'score': 0.2537003755569458},
#   {'start': 206,
#    'end': 324,
#    'text': 'In this review we first discuss the general characteristics of insulator elements and their associated protein factors.',
#    'is_title': False,
#    'doc_id': '24277632',
#    'score': 0.18847844004631042},
#   {'start': 326,
#    'end': 466,
#    'text': 'A growing collection of insulator proteins have been identified including a family of proteins whose expression is developmentally regulated.',
#    'is_title': False,
#    'doc_id': '24277632',
#    'score': 0.16808632016181946},
#   {'start': 468,
#    'end': 612,
#    'text': 'We next consider several unexpected discoveries that require us to completely rethink how insulators function (and how they can best be assayed).',
#    'is_title': False,
#    'doc_id': '24277632',
#    'score': 0.1661384105682373},
#   {'start': 614,
#    'end': 800,
#    'text': 'These discoveries also require a reevaluation of how insulators might restrict or orchestrate (by preventing or promoting) interactions between regulatory elements and their target genes.',
#    'is_title': False,
#    'doc_id': '24277632',
#    'score': 0.16746357083320618},
#   {'start': 802,
#    'end': 1058,
#    'text': 'We conclude by connecting these new insights into the mechanisms of insulator action to dynamic changes in the three-dimensional topology of the chromatin fiber and the generation of specific patterns of gene activity during development and differentiation.',
#    'is_title': False,
#    'doc_id': '24277632',
#    'score': 0.23895177245140076},
#   {'start': 0,
#    'end': 179,
#    'text': 'Grainyhead-like 2 regulates epithelial morphogenesis by establishing functional tight junctions through the organization of a molecular network among claudin3, claudin4, and Rab25.',
#    'is_title': True,
#    'doc_id': '22696678',
#    'score': 0.2452041208744049},
#   {'start': 0,
#    'end': 212,
#    'text': 'During development, epithelial progenitors establish intercellular junctions, including tight junctions (TJs), and form three-dimensional (3D) tissue structures, which are often associated with luminal structures.',
#    'is_title': False,
#    'doc_id': '22696678',
#    'score': 0.23981311917304993},
#   {'start': 214,
#    'end': 364,
#    'text': 'Here we identify grainyhead-like 2 (Grhl2) as a transcription factor that regulates the size of luminal space surrounded by polarized epithelial cells.',
#    'is_title': False,
#    'doc_id': '22696678',
#    'score': 0.16978731751441956},
#   {'start': 366,
#    'end': 510,
#    'text': 'We show that HPPL, a liver progenitor cell line, transfected with Grhl2 cDNA forms remarkably larger cysts than the control cells in 3D cultures.',
#    'is_title': False,
#    'doc_id': '22696678',
#    'score': 0.21562442183494568},
#   {'start': 512,
#    'end': 638,
#    'text': 'We find that Grhl2 up-regulates claudin (Cldn) 3 and Cldn4, and their functions are necessary for the formation of large cysts.',
#    'is_title': False,
#    'doc_id': '22696678',
#    'score': 0.17221930623054504},
#   {'start': 640,
#    'end': 696,
#    'text': 'Overexpression of Cldn3 alone induces the cyst expansion.',
#    'is_title': False,
#    'doc_id': '22696678',
#    'score': 0.1708110272884369},
#   {'start': 698,
#    'end': 793,
#    'text': 'In contrast, expression of Cldn4 alone does not induce expansion, as it is not localized at TJs.',
#    'is_title': False,
#    'doc_id': '22696678',
#    'score': 0.1740792691707611},
#   {'start': 795,
#    'end': 916,
#    'text': 'Of interest, Rab25, another Grhl2 target, not only increases the Cldn4 protein, but also enhances its localization at TJs.',
#    'is_title': False,
#    'doc_id': '22696678',
#    'score': 0.1804715096950531},
#   {'start': 918,
#    'end': 1141,
#    'text': 'Taken together, the results indicate that Grhl2 regulates epithelial morphogenesis through transcriptional up-regulation of Cldn3 and Cldn4, as well as of Rab25, which increases the Cldn4 protein and its localization at TJs.',
#    'is_title': False,
#    'doc_id': '22696678',
#    'score': 0.20861735939979553},
#   {'start': 1143,
#    'end': 1238,
#    'text': 'The results reveal a molecular network regulating epithelial lumen formation organized by Grhl2.',
#    'is_title': False,
#    'doc_id': '22696678',
#    'score': 0.217901349067688},
#   {'start': 0,
#    'end': 120,
#    'text': 'Structure function relations in PDZ-domain-containing proteins: Implications for protein networks in cellular signalling.',
#    'is_title': True,
#    'doc_id': '29485124',
#    'score': 0.21302258968353271},
#   {'start': 0,
#    'end': 143,
#    'text': 'Protein scaffolds as essential backbones for organization of supramolecular signalling complexes are a recurrent theme in several model systems.',
#    'is_title': False,
#    'doc_id': '29485124',
#    'score': 0.22705060243606567},
#   {'start': 145,
#    'end': 256,
#    'text': 'Scaffold proteins preferentially employ linear peptide binding motifs for recruiting their interaction partners.',
#    'is_title': False,
#    'doc_id': '29485124',
#    'score': 0.16901996731758118},
#   {'start': 258,
#    'end': 404,
#    'text': 'PDZ domains are one of the more commonly encountered peptide binding domains in several proteins including those involved in scaffolding functions.',
#    'is_title': False,
#    'doc_id': '29485124',
#    'score': 0.18271741271018982},
#   {'start': 406,
#    'end': 584,
#    'text': 'This domain is known for its promiscuity both in terms of ligand selection, mode of interaction with its ligands as well as its association with other protein interaction domains.',
#    'is_title': False,
#    'doc_id': '29485124',
#    'score': 0.18577778339385986},
#   {'start': 586,
#    'end': 681,
#    'text': 'PDZ domains are subject to several means of regulations by virtue of their functional diversity.',
#    'is_title': False,
#    'doc_id': '29485124',
#    'score': 0.17047181725502014},
#   {'start': 683,
#    'end': 834,
#    'text': 'Additionally, the PDZ domains are refractive to the effect of mutations and maintain their three-dimensional architecture under extreme mutational load.',
#    'is_title': False,
#    'doc_id': '29485124',
#    'score': 0.24068427085876465},
#   {'start': 836,
#    'end': 964,
#    'text': 'The biochemical and biophysical basis for this selectivity as well as promiscuity has been investigated and reviewed extensively.',
#    'is_title': False,
#    'doc_id': '29485124',
#    'score': 0.17380714416503906},
#   {'start': 966,
#    'end': 1154,
#    'text': 'The present review focuses on the plasticity inherent in PDZ domains and its implications for modular organization as well as evolution of cellular signalling pathways in higher eukaryotes.',
#    'is_title': False,
#    'doc_id': '29485124',
#    'score': 0.21782386302947998},
#   {'start': 0,
#    'end': 89,
#    'text': 'Interstitial flow regulates in\xa0vitro three-dimensional self-organized brain micro-vessels.',
#    'is_title': True,
#    'doc_id': '32988592',
#    'score': 0.23765534162521362},
#   {'start': 0,
#    'end': 122,
#    'text': 'Cell culture under medium flow has been shown to favor human brain microvascular endothelial cells function and maturation.',
#    'is_title': False,
#    'doc_id': '32988592',
#    'score': 0.17177963256835938},
#   {'start': 124,
#    'end': 453,
#    'text': 'Here a three-dimensional in\xa0vitro model of the human brain microvasculature, comprising brain microvascular endothelial cells but also astrocytes, pericytes and a collagen type I microfiber - fibrin based matrix, was cultured under continuous medium flow in a pressure driven microphysiological system (10\xa0kPa, in 60-30\xa0s cycles).',
#    'is_title': False,
#    'doc_id': '32988592',
#    'score': 0.24118348956108093},
#   {'start': 455,
#    'end': 528,
#    'text': 'The cells self-organized in micro-vessels perpendicular to the shear flow.',
#    'is_title': False,
#    'doc_id': '32988592',
#    'score': 0.17417865991592407},
#   {'start': 530,
#    'end': 827,
#    'text': 'Comparison with static culture showed that the resulting interstitial flow enhanced a more defined micro-vasculature network, with slightly more numerous lumens, and a higher expression of transporters, carriers and tight junction genes and proteins, essential to the blood-brain barrier functions.',
#    'is_title': False,
#    'doc_id': '32988592',
#    'score': 0.20121333003044128}]}

# %%
snippets["6057c78994d57fd879000034"]
# Out:
# [{'start': 0,
#   'end': 114,
#   'text': 'KLF4 is involved in the organization and regulation of pluripotency-associated three-dimensional enhancer networks.',
#   'is_title': True,
#   'doc_id': '31548608',
#   'score': 0.7081087231636047},
#  {'start': 0,
#   'end': 259,
#   'text': 'Cell fate transitions are accompanied by global transcriptional, epigenetic and topological changes driven by transcription factors, as is exemplified by reprogramming somatic cells to pluripotent stem cells through the expression of OCT4, KLF4, SOX2 and cMYC.',
#   'is_title': False,
#   'doc_id': '31548608',
#   'score': 0.15228056907653809},
#  {'start': 392,
#   'end': 669,
#   'text': 'Here, using KLF4 as a paradigm, we provide a transcription-factor-centric view of chromatin reorganization and its association with three-dimensional enhancer rewiring and transcriptional changes during the reprogramming of mouse embryonic fibroblasts to pluripotent stem cells.',
#   'is_title': False,
#   'doc_id': '31548608',
#   'score': 0.39797115325927734},
#  {'start': 671,
#   'end': 967,
#   'text': 'Inducible depletion of KLF factors in PSCs caused a genome-wide decrease in enhancer connectivity, whereas disruption of individual KLF4 binding sites within pluripotent-stem-cell-specific enhancers was sufficient to impair enhancer-promoter contacts and reduce the expression of associated genes.',
#   'is_title': False,
#   'doc_id': '31548608',
#   'score': 0.25990283489227295},
#  {'start': 0,
#   'end': 60,
#   'text': 'Pluripotency in 3D: genome organization in pluripotent cells.',
#   'is_title': True,
#   'doc_id': '23199754',
#   'score': 0.40288621187210083},
#  {'start': 0,
#   'end': 134,
#   'text': 'Cells face the challenge of storing two meters of DNA in the three-dimensional (3D) space of the nucleus that spans only a few microns.',
#   'is_title': False,
#   'doc_id': '23199754',
#   'score': 0.13167187571525574},
#  {'start': 136,
#   'end': 408,
#   'text': 'The nuclear organization that is required to overcome this challenge must allow for the accessibility of the gene regulatory machinery to the DNA and, in the case of embryonic stem cells (ESCs), for the transcriptional and epigenetic changes that accompany differentiation.',
#   'is_title': False,
#   'doc_id': '23199754',
#   'score': 0.2666993737220764},
#  {'start': 410,
#   'end': 532,
#   'text': 'Recent technological advances have allowed for the mapping of genome organization at an unprecedented resolution and scale.',
#   'is_title': False,
#   'doc_id': '23199754',
#   'score': 0.11587250232696533},
#  {'start': 534,
#   'end': 713,
#   'text': 'These breakthroughs have led to a deluge of new data, and a sophisticated understanding of the relationship between gene regulation and 3D genome organization is beginning to form.',
#   'is_title': False,
#   'doc_id': '23199754',
#   'score': 0.1825897991657257},
#  {'start': 715,
#   'end': 1076,
#   'text': 'In this review we summarize some of the recent findings illuminating the 3D structure of the eukaryotic genome, as well as the relationship between genome topology and function from the level of whole chromosomes to enhancer-promoter loops with a focus on features affecting genome organization in ESCs and changes in nuclear organization during differentiation.',
#   'is_title': False,
#   'doc_id': '23199754',
#   'score': 0.49772197008132935},
#  {'start': 0,
#   'end': 108,
#   'text': 'Genomic Rewiring of SOX2 Chromatin Interaction Network during Differentiation of ESCs to Postmitotic Neurons.',
#   'is_title': True,
#   'doc_id': '32553182',
#   'score': 0.29788559675216675},
#  {'start': 0,
#   'end': 128,
#   'text': 'Cellular differentiation requires dramatic changes in chromatin organization, transcriptional regulation, and protein production.',
#   'is_title': False,
#   'doc_id': '32553182',
#   'score': 0.14769163727760315},
#  {'start': 130,
#   'end': 467,
#   'text': 'To understand the regulatory connections between these processes, we generated proteomic, transcriptomic, and chromatin accessibility data during differentiation of mouse embryonic stem cells (ESCs) into postmitotic neurons and found extensive associations between different molecular layers within and across differentiation time points.',
#   'is_title': False,
#   'doc_id': '32553182',
#   'score': 0.2127506136894226},
#  {'start': 469,
#   'end': 690,
#   'text': 'We observed that SOX2, as a regulator of pluripotency and neuronal genes, redistributes from pluripotency enhancers to neuronal promoters during differentiation, likely driven by changes in its protein interaction network.',
#   'is_title': False,
#   'doc_id': '32553182',
#   'score': 0.5031372904777527},
#  {'start': 692,
#   'end': 912,
#   'text': 'We identified ATRX as a major SOX2 partner in neurons, whose co-localization correlated with an increase in active enhancer marks and increased expression of nearby genes, which we experimentally confirmed for three loci.',
#   'is_title': False,
#   'doc_id': '32553182',
#   'score': 0.15763896703720093},
#  {'start': 914,
#   'end': 1144,
#   'text': 'Collectively, our data provide key insights into the regulatory transformation of SOX2 during neuronal differentiation, and we highlight the significance of multi-omic approaches in understanding gene regulation in complex systems.',
#   'is_title': False,
#   'doc_id': '32553182',
#   'score': 0.10985422134399414},
#  {'start': 0,
#   'end': 128,
#   'text': 'Sall4 controls differentiation of pluripotent cells independently of the Nucleosome Remodelling and Deacetylation (NuRD) complex.',
#   'is_title': True,
#   'doc_id': '27471257',
#   'score': 0.24639463424682617},
#  {'start': 0,
#   'end': 116,
#   'text': 'Sall4 is an essential transcription factor for early mammalian development and is frequently overexpressed in cancer.',
#   'is_title': False,
#   'doc_id': '27471257',
#   'score': 0.0972265899181366},
#  {'start': 118,
#   'end': 275,
#   'text': 'Although it is reported to play an important role in embryonic stem cell (ESC) self-renewal, whether it is an essential pluripotency factor has been disputed.',
#   'is_title': False,
#   'doc_id': '27471257',
#   'score': 0.21590715646743774},
#  {'start': 277,
#   'end': 343,
#   'text': 'Here, we show that Sall4 is dispensable for mouse ESC pluripotency.',
#   'is_title': False,
#   'doc_id': '27471257',
#   'score': 0.23391544818878174},
#  {'start': 345,
#   'end': 545,
#   'text': 'Sall4 is an enhancer-binding protein that prevents precocious activation of the neural gene expression programme in ESCs but is not required for maintenance of the pluripotency gene regulatory network.',
#   'is_title': False,
#   'doc_id': '27471257',
#   'score': 0.4841834604740143},
#  {'start': 547,
#   'end': 824,
#   'text': 'Although a proportion of Sall4 protein physically associates with the Nucleosome Remodelling and Deacetylase (NuRD) complex, Sall4 neither recruits NuRD to chromatin nor influences transcription via NuRD; rather, free Sall4 protein regulates transcription independently of NuRD.',
#   'is_title': False,
#   'doc_id': '27471257',
#   'score': 0.10221952199935913},
#  {'start': 826,
#   'end': 1033,
#   'text': 'We propose a model whereby enhancer binding by Sall4 and other pluripotency-associated transcription factors is responsible for maintaining the balance between transcriptional programmes in pluripotent cells.',
#   'is_title': False,
#   'doc_id': '27471257',
#   'score': 0.44995638728141785},
#  {'start': 0,
#   'end': 188,
#   'text': 'DNA methylation of the Oct4A enhancers in embryonal carcinoma cells after etoposide treatment is associated with alternative splicing and altered pluripotency in reversibly senescent cells.',
#   'is_title': True,
#   'doc_id': '29372665',
#   'score': 0.36239680647850037},
#  {'start': 0,
#   'end': 140,
#   'text': 'The epigenetic mechanisms underlying chemoresistance in cancer cells resulting from drug-induced reversible senescence are poorly understood.',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.09827521443367004},
#  {'start': 142,
#   'end': 394,
#   'text': 'Chemoresistant ESC-like embryonal carcinoma PA1 cells treated with etoposide (ETO) were previously found to undergo prolonged G2 arrest with transient p53-dependent upregulation of opposing fate regulators, p21CIP1 (senescence) and OCT4A (self-renewal).',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.09764865040779114},
#  {'start': 396,
#   'end': 554,
#   'text': 'Here we report on the analysis of the DNA methylation state of the distal enhancer (DE) and proximal enhancer (PE) of the Oct4A gene during this dual response.',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.15672793984413147},
#  {'start': 556,
#   'end': 696,
#   'text': 'When compared to non-treated controls the methylation level increased from 1.3% to 12.5% and from 3% to 19.4%, in the DE and PE respectively.',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.09951764345169067},
#  {'start': 698,
#   'end': 804,
#   'text': 'It included CpG and non-CpG methylation, which was not chaotic but presented two patterns in each enhancer.',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.16123738884925842},
#  {'start': 806,
#   'end': 1071,
#   'text': 'Discorrelating with methylation of enhancers, the transcription of Oct4A increased, however, a strong expression of the splicing form Oct4B was also induced, along with down-regulation of the Oct4A partners of in the pluripotency/self-renewal network Sox2 and Lin28.',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.4819476008415222},
#  {'start': 1073,
#   'end': 1154,
#   'text': 'WB demonstrated disjoining of the OCT4A protein from the chromatin-bound fraction.',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.10324835777282715},
#  {'start': 1156,
#   'end': 1285,
#   'text': 'In survival clones, methylation of the DE was considerably erased, while some remnant of methylation of the PE was still observed.',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.09949445724487305},
#  {'start': 1287,
#   'end': 1473,
#   'text': 'The alternative splicing for Oct4B was reduced, Oct4A level insignificantly decreased, while the expression of Sox2 and Lin28 recovered, all three became proportionally above the control.',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.10344123840332031},
#  {'start': 1475,
#   'end': 1739,
#   'text': 'These findings indicate the involvement of the transient patterned methylation of the Oct4A enhancers and alternative splicing in the adaptive regulation of cell fate choice during the p53-dependant dual state of reversible senescence in ESC-like cancer stem cells.',
#   'is_title': False,
#   'doc_id': '29372665',
#   'score': 0.18598923087120056},
#  {'start': 0,
#   'end': 74,
#   'text': 'Role of ALKBH1 in the Core Transcriptional Network of Embryonic Stem Cells.',
#   'is_title': True,
#   'doc_id': '26765775',
#   'score': 0.1245814859867096},
#  {'start': 0,
#   'end': 171,
#   'text': 'BACKGROUND/AIMS\nALKBH1, an AlkB homologue in the 2-oxoglutarate and Fe2+ dependent hydroxylase family, is a histone dioxygenase that removes methyl groups from histone H2A.',
#   'is_title': False,
#   'doc_id': '26765775',
#   'score': 0.10476219654083252},
#  {'start': 173,
#   'end': 282,
#   'text': 'Studies of transgenic mice lacking Alkbh1 reveal that most Alkbh1-/- embryos die during embryonic development.',
#   'is_title': False,
#   'doc_id': '26765775',
#   'score': 0.09883207082748413},
#  {'start': 284,
#   'end': 537,
#   'text': 'Embryonic stem cells (ESCs) derived from these mice have prolonged expression of pluripotency markers and delayed induction of genes involved in neural differentiation, indicating that ALKBH1 is involved in regulation of pluripotency and differentiation.',
#   'is_title': False,
#   'doc_id': '26765775',
#   'score': 0.3430096507072449},
#  {'start': 539,
#   'end': 624,
#   'text': 'The aim of this study was to further investigate the role ALKBH1 in early development.',
#   'is_title': False,
#   'doc_id': '26765775',
#   'score': 0.10196158289909363},
#  {'start': 628,
#   'end': 839,
#   'text': 'METHODS\nDouble-filter methods for nitrocellulose-filter binding, dot blot, enzyme-linked immunosorbent assay (ELISA), immonocytochemistry, cell culture and differentiation of mouse ESCs, Co-IP and miRNA analysis.',
#   'is_title': False,
#   'doc_id': '26765775',
#   'score': 0.2339635193347931},
#  {'start': 843,
#   'end': 1032,
#   'text': 'RESULTS\nWe found that SOX2 and NANOG bind the ALKBH1 promoter, and we identified protein-protein interactions between ALKBH1 and these core transcription factors of the pluripotency network.',
#   'is_title': False,
#   'doc_id': '26765775',
#   'score': 0.4504778981208801},
#  {'start': 1034,
#   'end': 1201,
#   'text': 'Furthermore, lack of ALKBH1 affected the expression of developmentally important miRNAs, which are involved in the regulation of NANOG, SOX2 and neural differentiation.',
#   'is_title': False,
#   'doc_id': '26765775',
#   'score': 0.31529873609542847},
#  {'start': 1205,
#   'end': 1382,
#   'text': 'CONCLUSION\nOur results suggest that ALKBH1 interacts with the core transcriptional pluripotency network of ESCs and is involved in regulation of pluripotency and differentiation.',
#   'is_title': False,
#   'doc_id': '26765775',
#   'score': 0.4017235338687897},
#  {'start': 0,
#   'end': 128,
#   'text': 'Deep transcriptome profiling of mammalian stem cells supports a regulatory role for retrotransposons in pluripotency maintenance.',
#   'is_title': True,
#   'doc_id': '24777452',
#   'score': 0.24576252698898315},
#  {'start': 0,
#   'end': 190,
#   'text': 'The importance of microRNAs and long noncoding RNAs in the regulation of pluripotency has been documented; however, the noncoding components of stem cell gene networks remain largely unknown.',
#   'is_title': False,
#   'doc_id': '24777452',
#   'score': 0.38223984837532043},
#  {'start': 192,
#   'end': 340,
#   'text': 'Here we investigate the role of noncoding RNAs in the pluripotent state, with particular emphasis on nuclear and retrotransposon-derived transcripts.',
#   'is_title': False,
#   'doc_id': '24777452',
#   'score': 0.25615397095680237},
#  {'start': 342,
#   'end': 527,
#   'text': 'We have performed deep profiling of the nuclear and cytoplasmic transcriptomes of human and mouse stem cells, identifying a class of previously undetected stem cell-specific transcripts.',
#   'is_title': False,
#   'doc_id': '24777452',
#   'score': 0.10201424360275269},
#  {'start': 529,
#   'end': 668,
#   'text': 'We show that long terminal repeat (LTR)-derived transcripts contribute extensively to the complexity of the stem cell nuclear transcriptome.',
#   'is_title': False,
#   'doc_id': '24777452',
#   'score': 0.10034841299057007},
#  {'start': 670,
#   'end': 800,
#   'text': 'Some LTR-derived transcripts are associated with enhancer regions and are likely to be involved in the maintenance of pluripotency.',
#   'is_title': False,
#   'doc_id': '24777452',
#   'score': 0.45888859033584595},
#  {'start': 0,
#   'end': 121,
#   'text': 'KLF4 protein stability regulated by interaction with pluripotency transcription factors overrides transcriptional control.',
#   'is_title': True,
#   'doc_id': '31221664',
#   'score': 0.2726683020591736},
#  {'start': 0,
#   'end': 113,
#   'text': 'Embryonic stem (ES) cells are regulated by a network of transcription factors that maintain the pluripotent state.',
#   'is_title': False,
#   'doc_id': '31221664',
#   'score': 0.2761201858520508},
#  {'start': 115,
#   'end': 218,
#   'text': 'Differentiation relies on down-regulation of pluripotency transcription factors disrupting this network.',
#   'is_title': False,
#   'doc_id': '31221664',
#   'score': 0.3756549060344696},
#  {'start': 220,
#   'end': 597,
#   'text': 'While investigating transcriptional regulation of the pluripotency transcription factor Kruppel-like factor 4 (Klf4), we observed that homozygous deletion of distal enhancers caused a 17-fold decrease in Klf4 transcript but surprisingly decreased protein levels by less than twofold, indicating that posttranscriptional control of KLF4 protein overrides transcriptional control.',
#   'is_title': False,
#   'doc_id': '31221664',
#   'score': 0.4509628713130951},
#  {'start': 599,
#   'end': 698,
#   'text': 'The lack of sensitivity of KLF4 to transcription is due to high protein stability (half-life >24 h).',
#   'is_title': False,
#   'doc_id': '31221664',
#   'score': 0.11053293943405151},
#  {'start': 700,
#   'end': 1020,
#   'text': 'This stability is context-dependent and is disrupted during differentiation, as evidenced by a shift to a half-life of <2 h. KLF4 protein stability is maintained through interaction with other pluripotency transcription factors (NANOG, SOX2, and STAT3) that together facilitate association of KLF4 with RNA polymerase II.',
#   'is_title': False,
#   'doc_id': '31221664',
#   'score': 0.268865168094635},
#  {'start': 1022,
#   'end': 1131,
#   'text': 'In addition, the KLF4 DNA-binding and transactivation domains are required for optimal KLF4 protein stability.',
#   'is_title': False,
#   'doc_id': '31221664',
#   'score': 0.11121487617492676},
#  {'start': 1133,
#   'end': 1310,
#   'text': 'Posttranslational modification of KLF4 destabilizes the protein as cells exit the pluripotent state, and mutations that prevent this destabilization also prevent differentiation.',
#   'is_title': False,
#   'doc_id': '31221664',
#   'score': 0.2682322859764099},
#  {'start': 1312,
#   'end': 1569,
#   'text': 'These data indicate that the core pluripotency transcription factors are integrated by posttranslational mechanisms to maintain the pluripotent state and identify mutations that increase KLF4 protein stability while maintaining transcription factor function.',
#   'is_title': False,
#   'doc_id': '31221664',
#   'score': 0.23399245738983154},
#  {'start': 0,
#   'end': 171,
#   'text': 'Three-Dimensional Retinal Organoids Facilitate the Investigation of Retinal Ganglion Cell Development, Organization and Neurite Outgrowth from Human Pluripotent Stem Cells.',
#   'is_title': True,
#   'doc_id': '30266927',
#   'score': 0.46932312846183777},
#  {'start': 0,
#   'end': 235,
#   'text': 'Retinal organoids are three-dimensional structures derived from human pluripotent stem cells (hPSCs) which recapitulate the spatial and temporal differentiation of the retina, serving as effective in vitro models of retinal development.',
#   'is_title': False,
#   'doc_id': '30266927',
#   'score': 0.31366026401519775},
#  {'start': 237,
#   'end': 376,
#   'text': 'However, a lack of emphasis has been placed upon the development and organization of retinal ganglion cells (RGCs) within retinal organoids.',
#   'is_title': False,
#   'doc_id': '30266927',
#   'score': 0.13068628311157227},
#  {'start': 378,
#   'end': 623,
#   'text': 'Thus, initial efforts were made to characterize RGC differentiation throughout early stages of organoid development, with a clearly defined RGC layer developing in a temporally-appropriate manner expressing a complement of RGC-associated markers.',
#   'is_title': False,
#   'doc_id': '30266927',
#   'score': 0.10587576031684875},
#  {'start': 625,
#   'end': 804,
#   'text': 'Beyond studies of RGC development, retinal organoids may also prove useful for cellular replacement in which extensive axonal outgrowth is necessary to reach post-synaptic targets.',
#   'is_title': False,
#   'doc_id': '30266927',
#   'score': 0.10580062866210938},
#  {'start': 806,
#   'end': 973,
#   'text': 'Organoid-derived RGCs could help to elucidate factors promoting axonal outgrowth, thereby identifying approaches to circumvent a formidable obstacle to RGC replacement.',
#   'is_title': False,
#   'doc_id': '30266927',
#   'score': 0.10016009211540222},
#  {'start': 975,
#   'end': 1137,
#   'text': 'As such, additional efforts demonstrated significant enhancement of neurite outgrowth through modulation of both substrate composition and growth factor signaling.',
#   'is_title': False,
#   'doc_id': '30266927',
#   'score': 0.10293316841125488},
#  {'start': 1139,
#   'end': 1280,
#   'text': 'Additionally, organoid-derived RGCs exhibited diverse phenotypes, extending elaborate growth cones and expressing numerous guidance receptors.',
#   'is_title': False,
#   'doc_id': '30266927',
#   'score': 0.10172152519226074},
#  {'start': 1282,
#   'end': 1540,
#   'text': 'Collectively, these results establish retinal organoids as a valuable tool for studies of RGC development, and demonstrate the utility of organoid-derived RGCs as an effective platform to study factors influencing neurite outgrowth from organoid-derived RGCs.',
#   'is_title': False,
#   'doc_id': '30266927',
#   'score': 0.1039593517780304},
#  {'start': 0,
#   'end': 137,
#   'text': 'The Role of RNA Polymerase II Contiguity and Long-Range Interactions in the Regulation of Gene Expression in Human Pluripotent Stem Cells.',
#   'is_title': True,
#   'doc_id': '30863449',
#   'score': 0.30869418382644653},
#  {'start': 0,
#   'end': 189,
#   'text': 'The eukaryotic nucleus is a highly complex structure that carries out multiple functions primarily needed for gene expression, and among them, transcription seems to be the most fundamental.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.10597193241119385},
#  {'start': 191,
#   'end': 412,
#   'text': 'Diverse approaches have demonstrated that transcription takes place at discrete sites known as transcription factories, wherein RNA polymerase II (RNAP II) is attached to the factory and immobilized while transcribing DNA.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.10560482740402222},
#  {'start': 414,
#   'end': 598,
#   'text': 'It has been proposed that transcription factories promote chromatin loop formation, creating long-range interactions in which relatively distant genes can be transcribed simultaneously.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.10410195589065552},
#  {'start': 600,
#   'end': 909,
#   'text': 'In this study, we examined long-range interactions between the POU5F1 gene and genes previously identified as being POU5F1 enhancer-interacting, namely, CDYL, TLE2, RARG, and MSX1 (all involved in transcriptional regulation), in human pluripotent stem cells (hPSCs) and their early differentiated counterparts.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.4484449028968811},
#  {'start': 911,
#   'end': 1038,
#   'text': 'As a control gene, RUNX1 was used, which is expressed during hematopoietic differentiation and not associated with pluripotency.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.26265716552734375},
#  {'start': 1040,
#   'end': 1313,
#   'text': 'To reveal how these long-range interactions between POU5F1 and the selected genes change with the onset of differentiation and upon RNAP II inhibition, we performed three-dimensional fluorescence in situ hybridization (3D-FISH) followed by computational simulation analysis.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.14999845623970032},
#  {'start': 1315,
#   'end': 1519,
#   'text': 'Our analysis showed that the numbers of long-range interactions between specific genes decrease during differentiation, suggesting that the transcription of monitored genes is associated with pluripotency.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.25966376066207886},
#  {'start': 1521,
#   'end': 1640,
#   'text': 'In addition, we showed that upon inhibition of RNAP II, long-range associations do not disintegrate and remain constant.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.10640057921409607},
#  {'start': 1642,
#   'end': 1833,
#   'text': 'We also analyzed the distance distributions of these genes in the context of their positions in the nucleus and revealed that they tend to have similar patterns resembling normal distribution.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.10745862126350403},
#  {'start': 1835,
#   'end': 1945,
#   'text': 'Furthermore, we compared data created in vitro and in silico to assess the biological relevance of our results.',
#   'is_title': False,
#   'doc_id': '30863449',
#   'score': 0.10668230056762695},
#  {'start': 0,
#   'end': 49,
#   'text': 'DNA methylation and the core pluripotency network.',
#   'is_title': True,
#   'doc_id': '32562758',
#   'score': 0.28680557012557983},
#  {'start': 0,
#   'end': 87,
#   'text': 'From the onset of fertilization, the genome undergoes cell division and differentiation.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.10561397671699524},
#  {'start': 89,
#   'end': 227,
#   'text': 'All of these developmental transitions and differentiation processes include cell-specific signatures and gradual changes of the epigenome.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.10598498582839966},
#  {'start': 229,
#   'end': 380,
#   'text': 'Understanding what keeps stem cells in the pluripotent state and what leads to differentiation are fascinating and biomedically highly important issues.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.25422459840774536},
#  {'start': 382,
#   'end': 490,
#   'text': 'Numerous studies have identified genes, proteins, microRNAs and small molecules that exert essential effects.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.10321137309074402},
#  {'start': 492,
#   'end': 611,
#   'text': 'Notably, there exists a core pluripotency network that consists of several transcription factors and accessory proteins.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.2775859832763672},
#  {'start': 613,
#   'end': 719,
#   'text': 'Three eminent transcription factors, OCT4, SOX2 and NANOG, serve as hubs in this core pluripotency network.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.32389211654663086},
#  {'start': 721,
#   'end': 924,
#   'text': 'They bind to the enhancer regions of their target genes and modulate, among others, the expression levels of genes that are associated with Gene Ontology terms related to differentiation and self-renewal.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.17643365263938904},
#  {'start': 926,
#   'end': 1027,
#   'text': 'Also, much has been learned about the epigenetic rewiring processes during these changes of cell fate.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.10387203097343445},
#  {'start': 1029,
#   'end': 1106,
#   'text': 'For example, DNA methylation dynamics is pivotal during embryonic development.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.10323336720466614},
#  {'start': 1108,
#   'end': 1449,
#   'text': 'The main goal of this review is to highlight an intricate interplay of (a) DNA methyltransferases controlling the expression levels of core pluripotency factors by modulation of the DNA methylation levels in their enhancer regions, and of (b) the core pluripotency factors controlling the transcriptional regulation of DNA methyltransferases.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.4437042474746704},
#  {'start': 1451,
#   'end': 1601,
#   'text': 'We discuss these processes both at the global level and in atomistic detail based on information from structural studies and from computer simulations.',
#   'is_title': False,
#   'doc_id': '32562758',
#   'score': 0.10622531175613403},
#  {'start': 0,
#   'end': 130,
#   'text': 'Long-Range Enhancer Interactions Are Prevalent in Mouse Embryonic Stem Cells and Are Reorganized upon Pluripotent State Transition.',
#   'is_title': True,
#   'doc_id': '29514091',
#   'score': 0.3677775263786316},
#  {'start': 0,
#   'end': 148,
#   'text': 'Transcriptional enhancers, including super-enhancers (SEs), form physical interactions with promoters to regulate cell-type-specific gene expression.',
#   'is_title': False,
#   'doc_id': '29514091',
#   'score': 0.16429558396339417},
#  {'start': 150,
#   'end': 332,
#   'text': 'SEs are characterized by high transcription factor occupancy and large domains of active chromatin, and they are commonly assigned to target promoters using computational predictions.',
#   'is_title': False,
#   'doc_id': '29514091',
#   'score': 0.10517621040344238},
#  {'start': 334,
#   'end': 481,
#   'text': 'How promoter-SE interactions change upon cell state transitions, and whether transcription factors maintain SE interactions, have not been reported.',
#   'is_title': False,
#   'doc_id': '29514091',
#   'score': 0.16661447286605835},
#  {'start': 483,
#   'end': 600,
#   'text': 'Here, we used promoter-capture Hi-C to identify promoters that interact with SEs in mouse embryonic stem cells (ESCs).',
#   'is_title': False,
#   'doc_id': '29514091',
#   'score': 0.32012271881103516},
#  {'start': 602,
#   'end': 779,
#   'text': 'We found that SEs form complex, spatial networks in which individual SEs contact multiple promoters, and a rewiring of promoter-SE interactions occurs between pluripotent states.',
#   'is_title': False,
#   'doc_id': '29514091',
#   'score': 0.4290946424007416},
#  {'start': 781,
#   'end': 922,
#   'text': 'We also show that long-range promoter-SE interactions are more prevalent in ESCs than in epiblast stem cells (EpiSCs) or Nanog-deficient ESCs.',
#   'is_title': False,
#   'doc_id': '29514091',
#   'score': 0.3685828745365143},
#  {'start': 924,
#   'end': 1132,
#   'text': 'We conclude that SEs form cell-type-specific interaction networks that are partly dependent on core transcription factors, thereby providing insights into the gene regulatory organization of pluripotent cells.',
#   'is_title': False,
#   'doc_id': '29514091',
#   'score': 0.3570590019226074},
#  {'start': 0,
#   'end': 81,
#   'text': 'Gender Differences in Global but Not Targeted Demethylation in iPSC Reprogramming.',
#   'is_title': True,
#   'doc_id': '28147265',
#   'score': 0.10552334785461426},
#  {'start': 0,
#   'end': 188,
#   'text': 'Global DNA demethylation is an integral part of reprogramming processes in\xa0vivo and in\xa0vitro, but whether it occurs in the derivation of induced pluripotent stem cells (iPSCs) is not known.',
#   'is_title': False,
#   'doc_id': '28147265',
#   'score': 0.2805059552192688},
#  {'start': 190,
#   'end': 345,
#   'text': 'Here, we show that iPSC reprogramming involves both global and targeted demethylation, which are separable mechanistically and by their biological outcomes.',
#   'is_title': False,
#   'doc_id': '28147265',
#   'score': 0.10664835572242737},
#  {'start': 347,
#   'end': 483,
#   'text': 'Cells at intermediate-late stages of reprogramming undergo transient genome-wide demethylation, which is more pronounced in female cells.',
#   'is_title': False,
#   'doc_id': '28147265',
#   'score': 0.11006316542625427},
#  {'start': 485,
#   'end': 692,
#   'text': 'Global demethylation requires activation-induced cytidine deaminase (AID)-mediated downregulation of UHRF1 protein, and abolishing demethylation leaves thousands of hypermethylated regions in the iPSC genome.',
#   'is_title': False,
#   'doc_id': '28147265',
#   'score': 0.1180504858493805},
#  {'start': 694,
#   'end': 916,
#   'text': 'Independently of AID and global demethylation, regulatory regions, particularly ESC enhancers and super-enhancers, are specifically targeted for hypomethylation in association with transcription of the pluripotency network.',
#   'is_title': False,
#   'doc_id': '28147265',
#   'score': 0.4567837417125702},
#  {'start': 918,
#   'end': 1145,
#   'text': 'Our results show that global and targeted DNA demethylation are conserved and\xa0distinct reprogramming processes, presumably because of their respective roles in epigenetic memory erasure and in the establishment of cell identity.',
#   'is_title': False,
#   'doc_id': '28147265',
#   'score': 0.11022317409515381},
#  {'start': 0,
#   'end': 73,
#   'text': 'A transcribed enhancer dictates mesendoderm specification in pluripotency.',
#   'is_title': True,
#   'doc_id': '29180618',
#   'score': 0.40541893243789673},
#  {'start': 0,
#   'end': 108,
#   'text': 'Enhancers and long noncoding RNAs (lncRNAs) are key determinants of lineage specification during development.',
#   'is_title': False,
#   'doc_id': '29180618',
#   'score': 0.1812184453010559},
#  {'start': 110,
#   'end': 240,
#   'text': 'Here, we evaluate remodeling of the enhancer landscape and modulation of the lncRNA transcriptome during mesendoderm specification.',
#   'is_title': False,
#   'doc_id': '29180618',
#   'score': 0.18145865201950073},
#  {'start': 242,
#   'end': 485,
#   'text': 'We sort mesendodermal progenitors from differentiating embryonic stem cells (ESCs) according to Eomes expression, and find that enhancer usage is coordinated with mesendoderm-specific expression of key lineage-determining transcription factors.',
#   'is_title': False,
#   'doc_id': '29180618',
#   'score': 0.3563392162322998},
#  {'start': 487,
#   'end': 556,
#   'text': 'Many of these enhancers are associated with the expression of lncRNAs.',
#   'is_title': False,
#   'doc_id': '29180618',
#   'score': 0.18528583645820618},
#  {'start': 558,
#   'end': 763,
#   'text': 'Examination of ESC-specific enhancers interacting in three-dimensional space with mesendoderm-specifying transcription factor loci identifies MesEndoderm Transcriptional Enhancer Organizing Region (Meteor).',
#   'is_title': False,
#   'doc_id': '29180618',
#   'score': 0.26574966311454773},
#  {'start': 765,
#   'end': 985,
#   'text': 'Genetic and epigenetic manipulation of the Meteor enhancer reveal its indispensable role during mesendoderm specification and subsequent cardiogenic differentiation via transcription-independent and -dependent mechanisms.',
#   'is_title': False,
#   'doc_id': '29180618',
#   'score': 0.1795782446861267},
#  {'start': 987,
#   'end': 1084,
#   'text': 'Interestingly, Meteor-deleted ESCs are epigenetically redirected towards neuroectodermal lineages.',
#   'is_title': False,
#   'doc_id': '29180618',
#   'score': 0.2370816469192505},
#  {'start': 1086,
#   'end': 1288,
#   'text': 'Loci, topologically associating a transcribed enhancer and its cognate protein coding gene, appear to represent therefore a class of genomic elements controlling developmental competence in pluripotency.',
#   'is_title': False,
#   'doc_id': '29180618',
#   'score': 0.4206128716468811},
#  {'start': 0,
#   'end': 75,
#   'text': 'The interactomes of POU5F1 and SOX2 enhancers in human embryonic stem cells.',
#   'is_title': True,
#   'doc_id': '23549118',
#   'score': 0.18976709246635437},
#  {'start': 0,
#   'end': 152,
#   'text': 'The genes POU5F1 and SOX2 are critical for pluripotency and reprogramming, yet the chromosomal organization around these genes remains poorly understood.',
#   'is_title': False,
#   'doc_id': '23549118',
#   'score': 0.31996476650238037},
#  {'start': 154,
#   'end': 308,
#   'text': 'We assayed long-range chromosomal interactions on putative enhancers of POU5F1 and SOX2 genes in human embryonic stem cells (hESCs) using 4C-Seq technique.',
#   'is_title': False,
#   'doc_id': '23549118',
#   'score': 0.39866986870765686},
#  {'start': 310,
#   'end': 413,
#   'text': 'We discovered that their frequent interacting regions mainly overlap with early DNA replication domains.',
#   'is_title': False,
#   'doc_id': '23549118',
#   'score': 0.10612431168556213},
#  {'start': 415,
#   'end': 520,
#   'text': 'The interactomes are associated with active histone marks and enriched with 5-hydroxymethylcytosine sites.',
#   'is_title': False,
#   'doc_id': '23549118',
#   'score': 0.11248305439949036},
#  {'start': 522,
#   'end': 586,
#   'text': 'In hESCs, genes within the interactomes have elevated expression.',
#   'is_title': False,
#   'doc_id': '23549118',
#   'score': 0.25428152084350586},
#  {'start': 588,
#   'end': 675,
#   'text': 'Additionally, some genes associated with the POU5F1 enhancer contribute to pluripotency.',
#   'is_title': False,
#   'doc_id': '23549118',
#   'score': 0.41570454835891724},
#  {'start': 677,
#   'end': 816,
#   'text': 'Binding sites for multiple DNA binding proteins, including ATF3, CTCF, GABPA, JUND, NANOG, RAD21 and YY1, are enriched in both interactomes.',
#   'is_title': False,
#   'doc_id': '23549118',
#   'score': 0.25257909297943115},
#  {'start': 818,
#   'end': 958,
#   'text': 'The RARG locus, frequently interacting with the POU5F1 locus, has abundant RAD21 binding sites co-localized with other protein binding sites.',
#   'is_title': False,
#   'doc_id': '23549118',
#   'score': 0.11369895935058594},
#  {'start': 960,
#   'end': 1075,
#   'text': 'Thus the interactomes of these two pluripotency genes could be an important part of the regulatory network in hESCs.',
#   'is_title': False,
#   'doc_id': '23549118',
#   'score': 0.3358808755874634},
#  {'start': 0,
#   'end': 121,
#   'text': 'Coactivators p300 and CBP maintain the identity of mouse embryonic stem cells by mediating long-range chromatin structure.',
#   'is_title': True,
#   'doc_id': '24648406',
#   'score': 0.11095663905143738},
#  {'start': 0,
#   'end': 189,
#   'text': 'Master transcription factors Oct4, Sox2, and Nanog are required to maintain the pluripotency and self-renewal of embryonic stem cells (ESCs) by regulating a specific transcriptional network.',
#   'is_title': False,
#   'doc_id': '24648406',
#   'score': 0.3523593842983246},
#  {'start': 191,
#   'end': 440,
#   'text': 'A few other transcription factors have been shown to be important in ESCs by interacting with these master transcription factors; however, little is known about the transcriptional mechanisms regulated by coregulators (coactivators and corepressors).',
#   'is_title': False,
#   'doc_id': '24648406',
#   'score': 0.25966501235961914},
#  {'start': 442,
#   'end': 565,
#   'text': 'In this study, we examined the function of two highly homologous coactivators, p300 and CREB-binding protein (CBP), in ESCs.',
#   'is_title': False,
#   'doc_id': '24648406',
#   'score': 0.3012901842594147},
#  {'start': 567,
#   'end': 673,
#   'text': 'We find that these two coactivators play redundant roles in maintaining the undifferentiated state of ESCs.',
#   'is_title': False,
#   'doc_id': '24648406',
#   'score': 0.2795216143131256},
#  {'start': 675,
#   'end': 882,
#   'text': 'They are recruited by Nanog through physical interaction to Nanog binding loci, mediating the formation of long-range chromatin looping structures, which is essential to maintain ESC-specific gene expression.',
#   'is_title': False,
#   'doc_id': '24648406',
#   'score': 0.24124464392662048},
#  {'start': 884,
#   'end': 1219,
#   'text': 'Further functional studies reveal that the p300/CBP binding looping fragments contain enhancer activities, suggesting that the formation of p300/CBP-mediated looping structures may recruit distal enhancers to create a concentration of factors for the transcription activation of genes that are involved in self-renewal and pluripotency.',
#   'is_title': False,
#   'doc_id': '24648406',
#   'score': 0.4191829264163971},
#  {'start': 1221,
#   'end': 1485,
#   'text': 'Overall, these results provide a total new insight into the transcriptional regulation mechanism of coactivators p300 and CBP in ESCs, which is important in maintaining self-renewal and pluripotency, by mediating the formation of higher order chromosome structures.',
#   'is_title': False,
#   'doc_id': '24648406',
#   'score': 0.2935965359210968},
#  {'start': 0,
#   'end': 92,
#   'text': 'The three-dimensional genome: regulating gene expression during pluripotency and development.',
#   'is_title': True,
#   'doc_id': '29042476',
#   'score': 0.4218951165676117},
#  {'start': 0,
#   'end': 234,
#   'text': 'The precise expression of genes in time and space during embryogenesis is largely influenced by communication between enhancers and promoters, which is propagated and governed by the physical proximity of these elements in the nucleus.',
#   'is_title': False,
#   'doc_id': '29042476',
#   'score': 0.18712130188941956},
#  {'start': 236,
#   'end': 412,
#   'text': 'Here, we review how chromatin domains organize the genome by guiding enhancers to their target genes thereby preventing non-specific interactions with other neighboring regions.',
#   'is_title': False,
#   'doc_id': '29042476',
#   'score': 0.16716381907463074},
#  {'start': 414,
#   'end': 610,
#   'text': 'We also discuss the dynamics of chromatin interactions between enhancers and promoters, as well as the consequent changes in gene expression, that occur in pluripotent cells and during development.',
#   'is_title': False,
#   'doc_id': '29042476',
#   'score': 0.3728809356689453},
#  {'start': 612,
#   'end': 875,
#   'text': 'Finally, we evaluate how genomic changes such as deletions, inversions and duplications affect 3D chromatin configuration overall and lead to ectopic enhancer-promoter contacts, and thus gene misexpression, which can contribute to abnormal development and disease.',
#   'is_title': False,
#   'doc_id': '29042476',
#   'score': 0.22391435503959656},
#  {'start': 0,
#   'end': 110,
#   'text': 'Human Induced Pluripotent Stem Cell-Derived Endothelial Cells for Three-Dimensional Microphysiological Systems.',
#   'is_title': True,
#   'doc_id': '28622076',
#   'score': 0.36644959449768066},
#  {'start': 0,
#   'end': 165,
#   'text': 'Microphysiological systems (MPS), or "organ-on-a-chip" platforms, aim to recapitulate in vivo physiology using small-scale in vitro tissue models of human physiology.',
#   'is_title': False,
#   'doc_id': '28622076',
#   'score': 0.11068680882453918},
#  {'start': 167,
#   'end': 314,
#   'text': 'While significant efforts have been made to create vascularized tissues, most reports utilize primary endothelial cells that hinder reproducibility.',
#   'is_title': False,
#   'doc_id': '28622076',
#   'score': 0.10793313384056091},
#  {'start': 316,
#   'end': 483,
#   'text': 'In this study, we report the use of human induced pluripotent stem cell-derived endothelial cells (iPS-ECs) in developing three-dimensional (3D) microvascular networks.',
#   'is_title': False,
#   'doc_id': '28622076',
#   'score': 0.4245969355106354},
#  {'start': 485,
#   'end': 610,
#   'text': 'We established a CDH5-mCherry reporter iPS cell line, which expresses the vascular endothelial (VE)-cadherin fused to mCherry.',
#   'is_title': False,
#   'doc_id': '28622076',
#   'score': 0.1105991005897522},
#  {'start': 612,
#   'end': 896,
#   'text': 'The iPS-ECs demonstrate physiological functions characteristic of primary endothelial cells in a series of in vitro assays, including permeability, response to shear stress, and the expression of endothelial markers (CD31, von Willibrand factor, and endothelial nitric oxide synthase).',
#   'is_title': False,
#   'doc_id': '28622076',
#   'score': 0.1143372654914856},
#  {'start': 898,
#   'end': 1018,
#   'text': 'The iPS-ECs form stable, perfusable microvessels over the course of 14 days when cultured within 3D microfluidic devices.',
#   'is_title': False,
#   'doc_id': '28622076',
#   'score': 0.14495491981506348},
#  {'start': 1020,
#   'end': 1125,
#   'text': 'We also demonstrate that inhibition of TGF-β signaling improves vascular network formation by the iPS-ECs.',
#   'is_title': False,
#   'doc_id': '28622076',
#   'score': 0.12957125902175903},
#  {'start': 1127,
#   'end': 1304,
#   'text': 'We conclude that iPS-ECs can be a source of endothelial cells in MPS providing opportunities for human disease modeling and improving the reproducibility of 3D vascular networks.',
#   'is_title': False,
#   'doc_id': '28622076',
#   'score': 0.17117729783058167},
#  {'start': 0,
#   'end': 149,
#   'text': 'Profiling the long noncoding RNA interaction network in the regulatory elements of target genes by chromatin in situ reverse transcription sequencing.',
#   'is_title': True,
#   'doc_id': '31315906',
#   'score': 0.13434267044067383},
#  {'start': 0,
#   'end': 134,
#   'text': 'Long noncoding RNAs (lncRNAs) can regulate the activity of target genes by participating in the organization of chromatin architecture.',
#   'is_title': False,
#   'doc_id': '31315906',
#   'score': 0.1428370177745819},
#  {'start': 136,
#   'end': 399,
#   'text': 'We have devised a "chromatin-RNA in situ reverse transcription sequencing" (CRIST-seq) approach to profile the lncRNA interaction network in gene regulatory elements by combining the simplicity of RNA biotin labeling with the specificity of the CRISPR/Cas9 system.',
#   'is_title': False,
#   'doc_id': '31315906',
#   'score': 0.13011813163757324},
#  {'start': 401,
#   'end': 612,
#   'text': 'Using gene-specific gRNAs, we describe a pluripotency-specific lncRNA interacting network in the promoters of Sox2 and Pou5f1, two critical stem cell factors that are required for the maintenance of pluripotency.',
#   'is_title': False,
#   'doc_id': '31315906',
#   'score': 0.3435637354850769},
#  {'start': 614,
#   'end': 713,
#   'text': 'The promoter-interacting lncRNAs were specifically activated during reprogramming into pluripotency.',
#   'is_title': False,
#   'doc_id': '31315906',
#   'score': 0.4100116491317749},
#  {'start': 715,
#   'end': 789,
#   'text': 'Knockdown of these lncRNAs caused the stem cells to exit from pluripotency.',
#   'is_title': False,
#   'doc_id': '31315906',
#   'score': 0.27840617299079895},
#  {'start': 791,
#   'end': 967,
#   'text': 'In contrast, overexpression of the pluripotency-associated lncRNA activated the promoters of core stem cell factor genes and enhanced fibroblast reprogramming into pluripotency.',
#   'is_title': False,
#   'doc_id': '31315906',
#   'score': 0.32683682441711426},
#  {'start': 969,
#   'end': 1151,
#   'text': 'These CRIST-seq data suggest that the Sox2 and Pou5f1 promoters are organized within a unique lncRNA interaction network that determines the fate of pluripotency during reprogramming.',
#   'is_title': False,
#   'doc_id': '31315906',
#   'score': 0.3261426091194153},
#  {'start': 1153,
#   'end': 1260,
#   'text': 'This CRIST approach may be broadly used to map lncRNA interaction networks at target loci across the genome.',
#   'is_title': False,
#   'doc_id': '31315906',
#   'score': 0.12960880994796753},
#  {'start': 0,
#   'end': 76,
#   'text': 'Autophagy regulates homeostasis of pluripotency-associated proteins in hESCs.',
#   'is_title': True,
#   'doc_id': '24170349',
#   'score': 0.3461417555809021},
#  {'start': 0,
#   'end': 163,
#   'text': 'The pluripotency of embryonic stem cells (ESCs) is maintained by intracellular networks of many pluripotency-associated (PA) proteins such as OCT4, SOX2, and NANOG.',
#   'is_title': False,
#   'doc_id': '24170349',
#   'score': 0.4057402014732361},
#  {'start': 165,
#   'end': 269,
#   'text': 'However, the mechanisms underlying the regulation of protein homeostasis for pluripotency remain elusive.',
#   'is_title': False,
#   'doc_id': '24170349',
#   'score': 0.3350452780723572},
#  {'start': 271,
#   'end': 429,
#   'text': 'Here, we first demonstrate that autophagy acts together with the ubiquitin-proteasome system (UPS) to modulate the levels of PA proteins in human ESCs (hESCs).',
#   'is_title': False,
#   'doc_id': '24170349',
#   'score': 0.247096985578537},
#  {'start': 431,
#   'end': 519,
#   'text': 'Autophagy inhibition impaired the pluripotency despite increment of PA proteins in hESCs.',
#   'is_title': False,
#   'doc_id': '24170349',
#   'score': 0.27625173330307007},
#  {'start': 521,
#   'end': 614,
#   'text': 'Immunogold-electron microscopy confirmed localization of OCT4 molecules within autophagosomes.',
#   'is_title': False,
#   'doc_id': '24170349',
#   'score': 0.29148149490356445},
#  {'start': 616,
#   'end': 723,
#   'text': 'Also, knockdown of LC3 expression led to accumulation of PA proteins and reduction of pluripotency in hESCs.',
#   'is_title': False,
#   'doc_id': '24170349',
#   'score': 0.3075977861881256},
#  {'start': 725,
#   'end': 824,
#   'text': 'Interestingly, autophagy and the UPS showed differential kinetics in the degradation of PA proteins.',
#   'is_title': False,
#   'doc_id': '24170349',
#   'score': 0.11589106917381287},
#  {'start': 826,
#   'end': 997,
#   'text': 'Autophagy inhibition caused enhanced accumulation of both cytoplasmic and nuclear PA proteins, whereas the UPS inhibition led to preferentially degrade nuclear PA proteins.',
#   'is_title': False,
#   'doc_id': '24170349',
#   'score': 0.11371856927871704},
#  {'start': 999,
#   'end': 1139,
#   'text': 'Our findings suggest that autophagy modulates homeostasis of PA proteins, providing a new insight in the regulation of pluripotency in hESCs.',
#   'is_title': False,
#   'doc_id': '24170349',
#   'score': 0.35039037466049194},
#  {'start': 0,
#   'end': 100,
#   'text': 'Hmga2 is necessary for Otx2-dependent exit of embryonic stem cells from the pluripotent ground state.',
#   'is_title': True,
#   'doc_id': '27036552',
#   'score': 0.2798989415168762},
#  {'start': 0,
#   'end': 257,
# ...
#   'is_title': False,
#   'doc_id': '31035373',
#   'score': 0.16256222128868103},
#  {'start': 0,
#   'end': 87,
#   'text': 'A structural network associated with the kallikrein-kinin and renin-angiotensin systems.',
#   'is_title': True,
#   'doc_id': '20180650',
#   'score': 0.19083353877067566},
#  {'start': 0,
#   'end': 181,
#   'text': 'The kallikrein-kinin and renin-angiotensin (KKS-RAS) systems represent two highly regulated proteolytic systems that are involved in several physiological and pathological processes.',
#   'is_title': False,
#   'doc_id': '20180650',
#   'score': 0.1764903962612152},
#  {'start': 183,
#   'end': 438,
#   'text': 'Although their protein-protein interactions can be studied using experimental approaches, it is difficult to differentiate between direct physical interactions and functional associations, which do not involve direct atomic contacts between macromolecules.',
#   'is_title': False,
#   'doc_id': '20180650',
#   'score': 0.17073673009872437},
#  {'start': 440,
#   'end': 541,
#   'text': 'This information can be obtained from an atomic-resolution characterization of the protein interfaces.',
#   'is_title': False,
#   'doc_id': '20180650',
#   'score': 0.1675952672958374},
#  {'start': 543,
#   'end': 655,
#   'text': 'As a result of this, various three-dimensional-based protein-protein interaction databases have become available.',
#   'is_title': False,
#   'doc_id': '20180650',
#   'score': 0.2343921959400177},
#  {'start': 657,
#   'end': 824,
#   'text': 'To gain insight into the multilayered interaction of the KKS-RAS systems, we present a protein network that is built up on three-dimensional domain-domain interactions.',
#   'is_title': False,
#   'doc_id': '20180650',
#   'score': 0.27577322721481323},
#  {'start': 826,
#   'end': 1092,
#   'text': 'The essential domains that link these systems are as follows: Cystatin, Peptidase_C1, Thyroglobulin_1, Insulin, CIMR (Cation-independent mannose-6-phosphate receptor repeat), fn2 (Fibronectin type II domain), fn1 (Fibronectin type I domain), EGF, Trypsin, and Serpin.',
#   'is_title': False,
#   'doc_id': '20180650',
#   'score': 0.15941724181175232},
#  {'start': 1094,
#   'end': 1191,
#   'text': 'We found that the CIMR domain is located at the core of the network, thus connecting both systems.',
#   'is_title': False,
#   'doc_id': '20180650',
#   'score': 0.1862839162349701},
#  {'start': 1193,
#   'end': 1348,
#   'text': 'From the latter, all domain interactors up to level 4 were retrieved, thus displaying a more comprehensive representation of the KKS-RAS structural network.',
#   'is_title': False,
#   'doc_id': '20180650',
#   'score': 0.1840573251247406},
#  {'start': 0,
#   'end': 163,
#   'text': 'Ep-CAM transfection in thymic epithelial cell lines triggers the formation of dynamic actin-rich protrusions involved in the organization of epithelial cell layers.',
#   'is_title': True,
#   'doc_id': '11702195',
#   'score': 0.21225932240486145},
#  {'start': 0,
#   'end': 117,
#   'text': 'Thymic epithelium is organized in a highly connected three-dimensional network through which thymocytes differentiate.',
#   'is_title': False,
#   'doc_id': '11702195',
#   'score': 0.2675233483314514},
#  {'start': 119,
#   'end': 190,
#   'text': 'The molecular mechanisms underlying this organization are still unknown.',
#   'is_title': False,
#   'doc_id': '11702195',
#   'score': 0.19785204529762268},
#  {'start': 192,
#   'end': 347,
#   'text': 'In thymic medulla, a major site of tolerance induction, the development of the epithelial cell net is tightly regulated by the needs of thymocyte selection.',
#   'is_title': False,
#   'doc_id': '11702195',
#   'score': 0.16782167553901672},
#  {'start': 349,
#   'end': 426,
#   'text': 'These reticulated epithelial cells express high levels of the Ep-CAM molecule.',
#   'is_title': False,
#   'doc_id': '11702195',
#   'score': 0.16200625896453857},
#  {'start': 428,
#   'end': 689,
#   'text': 'Using different thymic epithelial cell lines as a model system, we found that transfection of Ep-CAM enhances cell growth and leads to a rapid reorganization of the actin cytoskeleton by inducing the formation of numerous stress fibers and long cell protrusions.',
#   'is_title': False,
#   'doc_id': '11702195',
#   'score': 0.1645474135875702},
#  {'start': 691,
#   'end': 837,
#   'text': 'Finally, the crosslinking of the extracellular domain of a chimeric CD25ec/Ep-CAMic molecule is sufficient to trigger the formation of protrusions.',
#   'is_title': False,
#   'doc_id': '11702195',
#   'score': 0.16455599665641785},
#  {'start': 839,
#   'end': 1036,
#   'text': 'These results suggest that expression of Ep-CAM might balance the organizing capacity of cadherin molecules and may be participating in the formation of a dynamic stromal cell network in the thymus.',
#   'is_title': False,
#   'doc_id': '11702195',
#   'score': 0.19614019989967346},
#  {'start': 0,
#   'end': 61,
#   'text': 'Organization of the cytokeratin network in an epithelial cell.',
#   'is_title': True,
#   'doc_id': '12850452',
#   'score': 0.2511327862739563},
#  {'start': 0,
#   'end': 89,
#   'text': 'The cytoskeleton is a dynamic three-dimensional structure mainly located in the cytoplasm.',
#   'is_title': False,
#   'doc_id': '12850452',
#   'score': 0.24609526991844177},
#  {'start': 91,
#   'end': 201,
#   'text': 'It is involved in many cell functions such as mechanical signal transduction and maintenance of cell integrity.',
#   'is_title': False,
#   'doc_id': '12850452',
#   'score': 0.18173441290855408},
#  {'start': 203,
#   'end': 353,
#   'text': 'Among the three cytoskeletal components, intermediate filaments (the cytokeratin in epithelial cells) are the best candidates for this mechanical role.',
#   'is_title': False,
#   'doc_id': '12850452',
#   'score': 0.1731824278831482},
#  {'start': 355,
#   'end': 539,
#   'text': 'A model of the establishment of the cytokeratin network of an epithelial cell is proposed to study the dependence of its structural organization on extracellular mechanical environment.',
#   'is_title': False,
#   'doc_id': '12850452',
#   'score': 0.2371448278427124},
#  {'start': 541,
#   'end': 667,
#   'text': 'To implicitly describe the latter and its effects on the intracellular domain, we use mechanically regulated protein synthesis.',
#   'is_title': False,
#   'doc_id': '12850452',
#   'score': 0.17581528425216675},
#  {'start': 669,
#   'end': 889,
#   'text': 'Our model is a hybrid of a partial differential equation of parabolic type, governing the evolution of the concentration of cytokeratin, and a set of stochastic differential equations describing the dynamics of filaments.',
#   'is_title': False,
#   'doc_id': '12850452',
#   'score': 0.17147886753082275},
#  {'start': 891,
#   'end': 1086,
#   'text': 'Each filament is described by a stochastic differential equation that reflects both the local interactions with the environment and the non-local interactions via the past history of the filament.',
#   'is_title': False,
#   'doc_id': '12850452',
#   'score': 0.17153769731521606},
#  {'start': 1088,
#   'end': 1164,
#   'text': 'A three-dimensional simulation model is derived from this mathematical model.',
#   'is_title': False,
#   'doc_id': '12850452',
#   'score': 0.23270553350448608},
#  {'start': 1166,
#   'end': 1340,
#   'text': 'This simulation model is then used to obtain examples of cytokeratin network architectures under given mechanical conditions, and to study the influence of several parameters.',
#   'is_title': False,
#   'doc_id': '12850452',
#   'score': 0.20032727718353271},
#  {'start': 0,
#   'end': 103,
#   'text': 'Making connections: insulators organize eukaryotic chromosomes into independent cis-regulatory networks.',
#   'is_title': True,
#   'doc_id': '24277632',
#   'score': 0.1947794258594513},
#  {'start': 0,
#   'end': 204,
#   'text': 'Insulators play a central role in subdividing the chromosome into a series of discrete topologically independent domains and in ensuring that enhancers and silencers contact their appropriate target genes.',
#   'is_title': False,
#   'doc_id': '24277632',
#   'score': 0.2537003755569458},
#  {'start': 206,
#   'end': 324,
#   'text': 'In this review we first discuss the general characteristics of insulator elements and their associated protein factors.',
#   'is_title': False,
#   'doc_id': '24277632',
#   'score': 0.18847844004631042},
#  {'start': 326,
#   'end': 466,
#   'text': 'A growing collection of insulator proteins have been identified including a family of proteins whose expression is developmentally regulated.',
#   'is_title': False,
#   'doc_id': '24277632',
#   'score': 0.16808632016181946},
#  {'start': 468,
#   'end': 612,
#   'text': 'We next consider several unexpected discoveries that require us to completely rethink how insulators function (and how they can best be assayed).',
#   'is_title': False,
#   'doc_id': '24277632',
#   'score': 0.1661384105682373},
#  {'start': 614,
#   'end': 800,
#   'text': 'These discoveries also require a reevaluation of how insulators might restrict or orchestrate (by preventing or promoting) interactions between regulatory elements and their target genes.',
#   'is_title': False,
#   'doc_id': '24277632',
#   'score': 0.16746357083320618},
#  {'start': 802,
#   'end': 1058,
#   'text': 'We conclude by connecting these new insights into the mechanisms of insulator action to dynamic changes in the three-dimensional topology of the chromatin fiber and the generation of specific patterns of gene activity during development and differentiation.',
#   'is_title': False,
#   'doc_id': '24277632',
#   'score': 0.23895177245140076},
#  {'start': 0,
#   'end': 179,
#   'text': 'Grainyhead-like 2 regulates epithelial morphogenesis by establishing functional tight junctions through the organization of a molecular network among claudin3, claudin4, and Rab25.',
#   'is_title': True,
#   'doc_id': '22696678',
#   'score': 0.2452041208744049},
#  {'start': 0,
#   'end': 212,
#   'text': 'During development, epithelial progenitors establish intercellular junctions, including tight junctions (TJs), and form three-dimensional (3D) tissue structures, which are often associated with luminal structures.',
#   'is_title': False,
#   'doc_id': '22696678',
#   'score': 0.23981311917304993},
#  {'start': 214,
#   'end': 364,
#   'text': 'Here we identify grainyhead-like 2 (Grhl2) as a transcription factor that regulates the size of luminal space surrounded by polarized epithelial cells.',
#   'is_title': False,
#   'doc_id': '22696678',
#   'score': 0.16978731751441956},
#  {'start': 366,
#   'end': 510,
#   'text': 'We show that HPPL, a liver progenitor cell line, transfected with Grhl2 cDNA forms remarkably larger cysts than the control cells in 3D cultures.',
#   'is_title': False,
#   'doc_id': '22696678',
#   'score': 0.21562442183494568},
#  {'start': 512,
#   'end': 638,
#   'text': 'We find that Grhl2 up-regulates claudin (Cldn) 3 and Cldn4, and their functions are necessary for the formation of large cysts.',
#   'is_title': False,
#   'doc_id': '22696678',
#   'score': 0.17221930623054504},
#  {'start': 640,
#   'end': 696,
#   'text': 'Overexpression of Cldn3 alone induces the cyst expansion.',
#   'is_title': False,
#   'doc_id': '22696678',
#   'score': 0.1708110272884369},
#  {'start': 698,
#   'end': 793,
#   'text': 'In contrast, expression of Cldn4 alone does not induce expansion, as it is not localized at TJs.',
#   'is_title': False,
#   'doc_id': '22696678',
#   'score': 0.1740792691707611},
#  {'start': 795,
#   'end': 916,
#   'text': 'Of interest, Rab25, another Grhl2 target, not only increases the Cldn4 protein, but also enhances its localization at TJs.',
#   'is_title': False,
#   'doc_id': '22696678',
#   'score': 0.1804715096950531},
#  {'start': 918,
#   'end': 1141,
#   'text': 'Taken together, the results indicate that Grhl2 regulates epithelial morphogenesis through transcriptional up-regulation of Cldn3 and Cldn4, as well as of Rab25, which increases the Cldn4 protein and its localization at TJs.',
#   'is_title': False,
#   'doc_id': '22696678',
#   'score': 0.20861735939979553},
#  {'start': 1143,
#   'end': 1238,
#   'text': 'The results reveal a molecular network regulating epithelial lumen formation organized by Grhl2.',
#   'is_title': False,
#   'doc_id': '22696678',
#   'score': 0.217901349067688},
#  {'start': 0,
#   'end': 120,
#   'text': 'Structure function relations in PDZ-domain-containing proteins: Implications for protein networks in cellular signalling.',
#   'is_title': True,
#   'doc_id': '29485124',
#   'score': 0.21302258968353271},
#  {'start': 0,
#   'end': 143,
#   'text': 'Protein scaffolds as essential backbones for organization of supramolecular signalling complexes are a recurrent theme in several model systems.',
#   'is_title': False,
#   'doc_id': '29485124',
#   'score': 0.22705060243606567},
#  {'start': 145,
#   'end': 256,
#   'text': 'Scaffold proteins preferentially employ linear peptide binding motifs for recruiting their interaction partners.',
#   'is_title': False,
#   'doc_id': '29485124',
#   'score': 0.16901996731758118},
#  {'start': 258,
#   'end': 404,
#   'text': 'PDZ domains are one of the more commonly encountered peptide binding domains in several proteins including those involved in scaffolding functions.',
#   'is_title': False,
#   'doc_id': '29485124',
#   'score': 0.18271741271018982},
#  {'start': 406,
#   'end': 584,
#   'text': 'This domain is known for its promiscuity both in terms of ligand selection, mode of interaction with its ligands as well as its association with other protein interaction domains.',
#   'is_title': False,
#   'doc_id': '29485124',
#   'score': 0.18577778339385986},
#  {'start': 586,
#   'end': 681,
#   'text': 'PDZ domains are subject to several means of regulations by virtue of their functional diversity.',
#   'is_title': False,
#   'doc_id': '29485124',
#   'score': 0.17047181725502014},
#  {'start': 683,
#   'end': 834,
#   'text': 'Additionally, the PDZ domains are refractive to the effect of mutations and maintain their three-dimensional architecture under extreme mutational load.',
#   'is_title': False,
#   'doc_id': '29485124',
#   'score': 0.24068427085876465},
#  {'start': 836,
#   'end': 964,
#   'text': 'The biochemical and biophysical basis for this selectivity as well as promiscuity has been investigated and reviewed extensively.',
#   'is_title': False,
#   'doc_id': '29485124',
#   'score': 0.17380714416503906},
#  {'start': 966,
#   'end': 1154,
#   'text': 'The present review focuses on the plasticity inherent in PDZ domains and its implications for modular organization as well as evolution of cellular signalling pathways in higher eukaryotes.',
#   'is_title': False,
#   'doc_id': '29485124',
#   'score': 0.21782386302947998},
#  {'start': 0,
#   'end': 89,
#   'text': 'Interstitial flow regulates in\xa0vitro three-dimensional self-organized brain micro-vessels.',
#   'is_title': True,
#   'doc_id': '32988592',
#   'score': 0.23765534162521362},
#  {'start': 0,
#   'end': 122,
#   'text': 'Cell culture under medium flow has been shown to favor human brain microvascular endothelial cells function and maturation.',
#   'is_title': False,
#   'doc_id': '32988592',
#   'score': 0.17177963256835938},
#  {'start': 124,
#   'end': 453,
#   'text': 'Here a three-dimensional in\xa0vitro model of the human brain microvasculature, comprising brain microvascular endothelial cells but also astrocytes, pericytes and a collagen type I microfiber - fibrin based matrix, was cultured under continuous medium flow in a pressure driven microphysiological system (10\xa0kPa, in 60-30\xa0s cycles).',
#   'is_title': False,
#   'doc_id': '32988592',
#   'score': 0.24118348956108093},
#  {'start': 455,
#   'end': 528,
#   'text': 'The cells self-organized in micro-vessels perpendicular to the shear flow.',
#   'is_title': False,
#   'doc_id': '32988592',
#   'score': 0.17417865991592407},
#  {'start': 530,
#   'end': 827,
#   'text': 'Comparison with static culture showed that the resulting interstitial flow enhanced a more defined micro-vasculature network, with slightly more numerous lumens, and a higher expression of transporters, carriers and tight junction genes and proteins, essential to the blood-brain barrier functions.',
#   'is_title': False,
#   'doc_id': '32988592',
#   'score': 0.20121333003044128}]

# %%
#run = create_document_run(queries, rerank, snippets)

# %%
with open("snippet_bioasq_9b_batch_03_snippetRank_byThreshold"+".csv", "w") as fOut:
    metrics = ["snippet_p@10", "snippet_r@10", "snippet_f1@10", "snippet_map@10", "snippet_gmap@10"]
    
    header = "f_name,threshold," + ",".join(metrics)+"\n"
    fOut.write(header)
    
    T = list(map(lambda x:x/10, range(0,101,1)))
    for t in T:
    
        snippets = snippetRank_byThreshold(rerank,t)
        _run = create_document_run(queries, rerank, snippets)
        m = evaluator.evaluate(_run)
        fOut.write("snippetRank_byThreshold," + str(t)+"," + ",".join([ str(m[n]) for n in metrics]) + "\n")
        fOut.flush()
    # snippetRank_byThreshold_and_TopK
# Out:
# Remove /tmp/tmpzgb_vo8x
# Remove /tmp/tmp30havt61
# Remove /tmp/tmpxg9g9cad
# Remove /tmp/tmpj6cn5epz
# Remove /tmp/tmpueui852v
# Remove /tmp/tmpbr1bg66v
# Remove /tmp/tmp33bsg8id
# Remove /tmp/tmpxlrmjsgg
# Remove /tmp/tmp7b1w23st
# Remove /tmp/tmpnp59en7u
# Remove /tmp/tmpw0sg6syr
# Remove /tmp/tmpxduwpg6b
# Remove /tmp/tmpqcfuq880
# Remove /tmp/tmpfc_z8xkm
# Remove /tmp/tmp0aa57tvm
# Remove /tmp/tmpm_82f2l1
# Remove /tmp/tmpv1n01i88
# Remove /tmp/tmpflmbqluy
# Remove /tmp/tmpeqk2jktm
# Remove /tmp/tmp0n8iv9vl
# Remove /tmp/tmpae8bglav
# Remove /tmp/tmp7inyg372
# Remove /tmp/tmpye5q_mw8
# Remove /tmp/tmpk3q4qy4j
# Remove /tmp/tmpei5_vmnn
# Remove /tmp/tmprr1epcqu
# Remove /tmp/tmpoa2srni9
# Remove /tmp/tmpkl80nh9m
# Remove /tmp/tmpqq8r6mdv
# Remove /tmp/tmpk7fgf2k4
# Remove /tmp/tmpem31wlj3
# Remove /tmp/tmp9m1mlr2n
# Remove /tmp/tmpo1d8mfie
# Remove /tmp/tmpc4fndxru
# Remove /tmp/tmp0sggiqh5
# Remove /tmp/tmpf3jycklk
# Remove /tmp/tmpms52i_6p
# Remove /tmp/tmpi_b0yiil
# Remove /tmp/tmp1zva_qaa
# Remove /tmp/tmp5c142fc_
# Remove /tmp/tmpxpcqyk23
# Remove /tmp/tmpnq1xoie9
# Remove /tmp/tmpyp2r1dgo
# Remove /tmp/tmp_h7tradf
# Remove /tmp/tmpg_xpemwi
# Remove /tmp/tmpwcxg29x5
# Remove /tmp/tmpuz589ra_
# Remove /tmp/tmpwz3wxnn1
# Remove /tmp/tmpxr48whi9
# Remove /tmp/tmpcv9l7_39
# Remove /tmp/tmp6e4xtobc
# Remove /tmp/tmpw_noa1ho
# Remove /tmp/tmpp8zxxkzj
# Remove /tmp/tmpougsnprr
# Remove /tmp/tmpqsihondi
# Remove /tmp/tmp7pqdifzc
# Remove /tmp/tmp7prg5ulq
# Remove /tmp/tmpxl_dbo3e
# Remove /tmp/tmpqjs1ubdl
# Remove /tmp/tmp0ogt63tx
# Remove /tmp/tmp2j96gi83
# Remove /tmp/tmpk_uyzri8
# Remove /tmp/tmpc5rrb0za
# Remove /tmp/tmp06f93p9_
# Remove /tmp/tmp5jk2sdss
# Remove /tmp/tmplg2_d1a_
# Remove /tmp/tmpzlskm_kp
# Remove /tmp/tmpvfes15v_
# Remove /tmp/tmp1n8w5w31
# Remove /tmp/tmp0s7n8304
# Remove /tmp/tmpa93vje6z
# Remove /tmp/tmpmqcwyri0
# Remove /tmp/tmpp8irsbz_
# Remove /tmp/tmpmt0soae6
# Remove /tmp/tmp9ufrjes9
# Remove /tmp/tmpmx9t4lzy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-cc046dbdc060> in <module>
#      10         snippets = snippetRank_byThreshold(rerank,t)
#      11         _run = create_document_run(queries, rerank, snippets)
# ---> 12         m = evaluator.evaluate(_run)
#      13         fOut.write("snippetRank_byThreshold," + str(t)+"," + ",".join([ str(m[n]) for n in metrics]) + "\n")
#      14         fOut.flush()
#
# ~/BioASQ-9b/py-bioasq/lib/python3.6/site-packages/mmnrm/evaluation.py in evaluate(self, run)
#     275             if self.write_f is not None:
#     276                 path = os.path.join(temp_dir, "retrived.json")
# --> 277                 self.write_f(run, path)
#     278             else:
#     279                 path = run
#
# ~/BioASQ-9b/utils.py in write_as_bioasq(run, file, max_docs, max_snippets)
#      72
#      73 def write_as_bioasq(run, file, max_docs=10, max_snippets=10):
# ---> 74     final_run = copy.deepcopy(run)
#      75
#      76     for query in final_run:
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /usr/lib/python3.6/copy.py in _deepcopy_list(x, memo, deepcopy)
#     213     append = y.append
#     214     for a in x:
# --> 215         append(deepcopy(a, memo))
#     216     return y
#     217 d[list] = _deepcopy_list
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /usr/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /usr/lib/python3.6/copy.py in _deepcopy_list(x, memo, deepcopy)
#     213     append = y.append
#     214     for a in x:
# --> 215         append(deepcopy(a, memo))
#     216     return y
#     217 d[list] = _deepcopy_list
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /usr/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /usr/lib/python3.6/copy.py in _deepcopy_list(x, memo, deepcopy)
#     213     append = y.append
#     214     for a in x:
# --> 215         append(deepcopy(a, memo))
#     216     return y
#     217 d[list] = _deepcopy_list
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /usr/lib/python3.6/copy.py in _deepcopy_dict(x, memo, deepcopy)
#     238     memo[id(x)] = y
#     239     for key, value in x.items():
# --> 240         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     241     return y
#     242 d[dict] = _deepcopy_dict
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     144         return y
#     145
# --> 146     cls = type(x)
#     147
#     148     copier = _deepcopy_dispatch.get(cls)
#
# KeyboardInterrupt:

# %%
import itertools

with open("snippet_bioasq_9b_batch_03_snippetRank_byThreshold_and_TopK"+".csv", "w") as fOut:
    metrics = ["snippet_p@10", "snippet_r@10", "snippet_f1@10", "snippet_map@10", "snippet_gmap@10"]
    
    header = "f_name,threshold,topK" + ",".join(metrics)+"\n"
    fOut.write(header)
    
    T = list(map(lambda x:x/100, range(0,51,1)))
    TOPK = list(range(1,5,1))
    
    combinations = list(itertools.product(T,TOPK))
    
    for t,k in combinations:
    
        snippets = snippetRank_byThreshold_and_TopK(rerank,t,k)
        _run = create_document_run(queries, rerank, snippets)
        m = evaluator.evaluate(_run)
        fOut.write("snippetRank_byThreshold_and_TopK," + str(t)+"," +str(k)+","+ ",".join([ str(m[n]) for n in metrics]) + "\n")
        fOut.flush()
# Out:
# Remove /tmp/tmp1wwvt48z
# Remove /tmp/tmpaequkr0h
# Remove /tmp/tmpvc15mw42
# Remove /tmp/tmp98uetr0j
# Remove /tmp/tmpq70ab_3_
# Remove /tmp/tmpjp6haap8
# Remove /tmp/tmpmw6qpwar
# Remove /tmp/tmpfxpq94lf
# Remove /tmp/tmp9q80cql1
# Remove /tmp/tmp0mox8ihe
# Remove /tmp/tmpyq6e8iad
# Remove /tmp/tmpp75bed5a
# Remove /tmp/tmp6egxz5qb
# Remove /tmp/tmpsanj4sf1
# Remove /tmp/tmp2ogewxgl
# Remove /tmp/tmputfaywd6
# Remove /tmp/tmpt165w6a1
# Remove /tmp/tmp1bfbhyka
# Remove /tmp/tmpjijj1xt0
# Remove /tmp/tmpctmbm9z1
# Remove /tmp/tmpkib_y8up
# Remove /tmp/tmpy3pql0ef
# Remove /tmp/tmp2lm4v1ek
# Remove /tmp/tmpv19mmu9e
# Remove /tmp/tmpovzu979o
# Remove /tmp/tmpfvagcnu_
# Remove /tmp/tmphe_pizsr
# Remove /tmp/tmpuoyt2so8
# Remove /tmp/tmpep9jfzpl
# Remove /tmp/tmp1svccdsy
# Remove /tmp/tmpyyifnwot
# Remove /tmp/tmpwgfrg8_b
# Remove /tmp/tmp6atqx1gn
# Remove /tmp/tmp2a9wm7qi
# Remove /tmp/tmpidldt3t4
# Remove /tmp/tmpjgd1ef77
# Remove /tmp/tmplan_kdis
# Remove /tmp/tmp0uaywycy
# Remove /tmp/tmppnlwxxj7
# Remove /tmp/tmpz2_04w8p
# Remove /tmp/tmpdwlvx8q6
# Remove /tmp/tmp42lt43sz
# Remove /tmp/tmpon8sbz_q
# Remove /tmp/tmps_pgeezk
# Remove /tmp/tmplq7j9aex
# Remove /tmp/tmpxenrxh73
# Remove /tmp/tmphty0cmyb
# Remove /tmp/tmplrlwa0pf
# Remove /tmp/tmp3vjk5o4y
# Remove /tmp/tmpyqzj4itq
# Remove /tmp/tmph3ub85ic
# Remove /tmp/tmp949kiw95
# Remove /tmp/tmpd0g_86fx
# Remove /tmp/tmp1qkzy2kr
# Remove /tmp/tmpmz5f_nc2
# Remove /tmp/tmpxazjzybr
# Remove /tmp/tmpofpn2tw8
# Remove /tmp/tmpeewd_vja
# Remove /tmp/tmphjceet4x
# Remove /tmp/tmpgs9qu8to
# Remove /tmp/tmpdp3vm3sz
# Remove /tmp/tmp9u8neb83
# Remove /tmp/tmp5fl65d0g
# Remove /tmp/tmp2vfu9whw
# Remove /tmp/tmpz3h94a7b
# Remove /tmp/tmppk9zjvpv
# Remove /tmp/tmpoznd_n9c
# Remove /tmp/tmpdri4tlfq
# Remove /tmp/tmpofkq3nxt
# Remove /tmp/tmp8fp8xx_z
# Remove /tmp/tmpgk7a95js
# Remove /tmp/tmpcmw4ldty
# Remove /tmp/tmp2as5wuuj
# Remove /tmp/tmpwcyj14wv
# Remove /tmp/tmpld5ou06n
# Remove /tmp/tmpmiaum2pl
# Remove /tmp/tmpcwbx1wy1
# Remove /tmp/tmp43sl1elk
# Remove /tmp/tmp7pw92r9s
# Remove /tmp/tmpgvsl95aw
# Remove /tmp/tmpzf3tu0x6
# Remove /tmp/tmpo9vow96b
# Remove /tmp/tmpam6c96k5
# Remove /tmp/tmpzi5r_skt
# Remove /tmp/tmp1kr1ewxd
# Remove /tmp/tmpf4ajfzi8
# Remove /tmp/tmpy6i_0bvy
# Remove /tmp/tmpptolpjef
# Remove /tmp/tmpegqmjwob
# Remove /tmp/tmp1j80ehgd
# Remove /tmp/tmphc1y9n0v
# Remove /tmp/tmp0px5io0u
# Remove /tmp/tmp06crt5h_
# Remove /tmp/tmpa0ox28wc
# Remove /tmp/tmp87e0vokd
# Remove /tmp/tmpsh0ek7fk
# Remove /tmp/tmpi2pgzkh6
# Remove /tmp/tmp1z05mrrx
# Remove /tmp/tmpr71yhuus
# Remove /tmp/tmpmaied4gd
# Remove /tmp/tmp8_ynvwz4
# Remove /tmp/tmpt7_lgrf5
# Remove /tmp/tmpa9w2dqm8
# Remove /tmp/tmppxqh9fqb
# Remove /tmp/tmpkpg4h7q3
# Remove /tmp/tmpds93enhx
# Remove /tmp/tmpu201w8t2
# Remove /tmp/tmph0i3xvsb
# Remove /tmp/tmpzvggpgs1
# Remove /tmp/tmplw32rf1f
# Remove /tmp/tmpg85lmuu2
# Remove /tmp/tmpm1067zfu
# Remove /tmp/tmpyj7g9v6i
# Remove /tmp/tmpsg_t8d9v
# Remove /tmp/tmpkxfu8kkn
# Remove /tmp/tmpw10bamau
# Remove /tmp/tmpiv7hh2ic
# Remove /tmp/tmp_ur8kkmn
# Remove /tmp/tmp_2ak_e52
# Remove /tmp/tmpk1p3lcmk
# Remove /tmp/tmpqbca3b5f
# Remove /tmp/tmpwv89461n
# Remove /tmp/tmpivusu9ue
# Remove /tmp/tmpz1svx5zh
# Remove /tmp/tmpzx78px1k
# Remove /tmp/tmpph_lgr79
# Remove /tmp/tmpljvsau1u
# Remove /tmp/tmpeey8ac12
# Remove /tmp/tmpnu0bj8yc
# Remove /tmp/tmpx8q4dsx4
# Remove /tmp/tmpwbgklj28
# Remove /tmp/tmp_7qf_rrk
# Remove /tmp/tmpqy0llt5w
# Remove /tmp/tmpuxx2llz9
# Remove /tmp/tmp7k3wsbiw
# Remove /tmp/tmpvh247kad
# Remove /tmp/tmpcka9hhyy
# Remove /tmp/tmpav9t9f3h
# Remove /tmp/tmp9p241ezw
# Remove /tmp/tmp4ojz5fss
# Remove /tmp/tmprlctmyca
# Remove /tmp/tmp9abs47gg
# Remove /tmp/tmpe2c27_0c
# Remove /tmp/tmp08wdtzoz
# Remove /tmp/tmplwka9gyi
# Remove /tmp/tmp63ftxrz3
# Remove /tmp/tmph5xqb7xr
# Remove /tmp/tmpe3702bg0
# Remove /tmp/tmpwlnn2ciu
# Remove /tmp/tmpqeixlcb9
# Remove /tmp/tmpg2m__iay
# Remove /tmp/tmpfx2a1e34
# Remove /tmp/tmpq0zn5khd
# Remove /tmp/tmp3bocwlvs
# Remove /tmp/tmpp_38if6y
# Remove /tmp/tmpcemmrvnm
# Remove /tmp/tmpo49fshjk
# Remove /tmp/tmprv5xzgph
# Remove /tmp/tmpwoyaixuc
# Remove /tmp/tmpzkwnjm91
# Remove /tmp/tmpqkdlohq5
# Remove /tmp/tmpdlof3i1q
# Remove /tmp/tmpohzjbjf0
# Remove /tmp/tmp0yzhc7k9
# Remove /tmp/tmprrnqrvdc
# Remove /tmp/tmpyhu1fye5
# Remove /tmp/tmp135nenil
# Remove /tmp/tmpu8l3gp1a
# Remove /tmp/tmprk8y2mmt
# Remove /tmp/tmp7jmxelsp
# Remove /tmp/tmpkmrs8rsn
# Remove /tmp/tmpnnbmk7za
# Remove /tmp/tmpdbesxpzk
# Remove /tmp/tmpxc4rw3e2
# Remove /tmp/tmpd6vqydy7
# Remove /tmp/tmpvcejl8xj
# Remove /tmp/tmpvn5b3gkx
# Remove /tmp/tmp_n4gb_b7
# Remove /tmp/tmp54a6e_b5
# Remove /tmp/tmp3i9y1587
# Remove /tmp/tmpkmahivlm
# Remove /tmp/tmpozhn_irn
# Remove /tmp/tmp914g0hli
# Remove /tmp/tmpkx092q9h
# Remove /tmp/tmp1l95308b
# Remove /tmp/tmpdrlxcyx2
# Remove /tmp/tmp6lzzxs80
# Remove /tmp/tmp70hd5ysa
# Remove /tmp/tmplu5udyhk
# Remove /tmp/tmp27rst2wm
# Remove /tmp/tmpcgyzhisj
# Remove /tmp/tmpgyvo51f4
# Remove /tmp/tmpj7b2hpje
# Remove /tmp/tmpfav3esa_
# Remove /tmp/tmpguqe5e75
# Remove /tmp/tmpfsvhfnvf
# Remove /tmp/tmp0c7f2jp7
# Remove /tmp/tmpbw38gbp0
# Remove /tmp/tmp3pjs18m3
# Remove /tmp/tmpczvbj64t
# Remove /tmp/tmpa_z7q6aw
# Remove /tmp/tmpqmgesz7f
# Remove /tmp/tmpoo9j6gn7
# Remove /tmp/tmp8dc6zf0j

# %%
import pandas as pd
df = pd.read_csv("snippet_bioasq_9b_batch_03_snippetRank_byThreshold.csv")
df = df.sort_values('snippet_f1@10',ascending=False)

# %%
import pandas as pd
df = pd.read_csv("snippet_bioasq_9b_batch_03_snippetRank_byThreshold_and_TopK.csv")
df.sort_values('snippet_f1@10',ascending=False)
# Out:
#                                   f_name  threshold  topKsnippet_p@10  \
# snippetRank_byThreshold_and_TopK    0.08          1          0.167207
# snippetRank_byThreshold_and_TopK    0.12          1          0.169362
# snippetRank_byThreshold_and_TopK    0.11          1          0.167702
# snippetRank_byThreshold_and_TopK    0.09          1          0.166875
# snippetRank_byThreshold_and_TopK    0.10          1          0.167288
# ...                                  ...        ...               ...
# snippetRank_byThreshold_and_TopK    0.32          2          0.139549
# snippetRank_byThreshold_and_TopK    0.33          4          0.138182
# snippetRank_byThreshold_and_TopK    0.33          3          0.138182
# snippetRank_byThreshold_and_TopK    0.32          3          0.137730
# snippetRank_byThreshold_and_TopK    0.32          4          0.137730
#
#                                   snippet_r@10  snippet_f1@10  snippet_map@10  \
# snippetRank_byThreshold_and_TopK      0.215893       0.178072        0.672674
# snippetRank_byThreshold_and_TopK      0.212623       0.177712        0.643631
# snippetRank_byThreshold_and_TopK      0.213821       0.177454        0.652801
# snippetRank_byThreshold_and_TopK      0.214446       0.177414        0.659153
# snippetRank_byThreshold_and_TopK      0.213821       0.177234        0.653516
# ...                                        ...            ...             ...
# snippetRank_byThreshold_and_TopK      0.227787       0.160634        0.564154
# snippetRank_byThreshold_and_TopK      0.231159       0.160190        0.561348
# snippetRank_byThreshold_and_TopK      0.231159       0.160190        0.561348
# snippetRank_byThreshold_and_TopK      0.230491       0.159620        0.566314
# snippetRank_byThreshold_and_TopK      0.230491       0.159620        0.566314
#
#                                   snippet_gmap@10
# snippetRank_byThreshold_and_TopK         0.000465
# snippetRank_byThreshold_and_TopK         0.000459
# snippetRank_byThreshold_and_TopK         0.000461
# snippetRank_byThreshold_and_TopK         0.000463
# snippetRank_byThreshold_and_TopK         0.000462
# ...                                           ...
# snippetRank_byThreshold_and_TopK         0.000898
# snippetRank_byThreshold_and_TopK         0.000900
# snippetRank_byThreshold_and_TopK         0.000900
# snippetRank_byThreshold_and_TopK         0.000901
# snippetRank_byThreshold_and_TopK         0.000901
#
# [204 rows x 7 columns]

# %%
punkt_sent_tokenizer = PunktSentenceTokenizer().span_tokenize

# %%
list(punkt_sent_tokenizer("asdfa. asdf asdf asdf. asdf asdf"))
# Out:
# [(0, 6), (7, 22), (23, 32)]

# %%
# Test Callback Validation with snippets
from mmnrm.callbacks import Validation
from mmnrm.evaluation import BioASQ_JavaEvaluator

evaluator = BioASQ_JavaEvaluator("/home/tiagoalmeida/BioASQ-9b/yearly_data/8B5_golden.json", 
                                 "/home/tiagoalmeida/BioASQ-9b/BioASQEvaluator/BioASQEvaluation.jar",
                                 write_as_bioasq)

validation_collection = TestCollectionV2.load("validation_batch_05_0.4_0.44_100")\
                                    .batch_size(100)\
                                    .set_name("Validation TOP (recall) 100")
validation_collection.evaluator = evaluator

validation_collection.save("validation_wSnippets_batch_05_0.4_0.44_100")

# %%
from mmnrm.callbacks import Validation
from mmnrm.evaluation import BioASQ_JavaEvaluator

def snippetRank_byThreshold(threshold):
    
    def snippetRank(results):
    
        snippets_results = {}
        # this will follow the document order first
        for q in results.keys():
            snippets_results[q] = [y for y in flat_list([x["snippets"] for x in results[q]]) if y["score"] >= threshold]

        return snippets_results
    
    return snippetRank

test_input_generator = get_test_generator_for_model(ranking_model, use_joint=True)

evaluator = BioASQ_JavaEvaluator("/home/tiagoalmeida/BioASQ-9b/yearly_data/8B5_golden.json", 
                                 "/home/tiagoalmeida/BioASQ-9b/BioASQEvaluator/BioASQEvaluation.jar",
                                 write_as_bioasq)

validation_collection = TestCollectionV2.load("validation_batch_05_0.4_0.44_100")\
                                    .batch_size(100)\
                                    .set_transform_inputs_fn(test_input_generator)\
                                    .set_name("Validation TOP (recall) 100")

validation_collection.evaluator = evaluator

snippet_rank_f = snippetRank_byThreshold(0.08) 

val = Validation(validation_collection = [validation_collection],# TODO
                 output_metrics=["doc_r@10", "doc_map@10","snippet_f1@10","snippet_map@10"],
                 path_store = None,
                 snippet_rank_f = snippet_rank_f)

# %%
val.evaluate(ranking_model.predict, validation_collection)
# Out:
# Evaluation 50 | avg 50-time 0.3404881954193115
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Remove /tmp/tmpqi5vduy0
# {'doc_p@10': '0.1499999999999999',
#  'doc_r@10': '0.5829252969252969',
#  'doc_f1@10': '0.21479179024935535',
#  'doc_map@10': '0.4581660918997229',
#  'doc_gmap@10': '0.02964828870067375',
#  'snippet_p@10': '0.17166116324064698',
#  'snippet_r@10': '0.28734795914322975',
#  'snippet_f1@10': '0.19953835567849598',
#  'snippet_map@10': '0.7424392903661619',
#  'snippet_gmap@10': '0.003843435329089425'}

# %%
validation_collection.save("validation_wSnippets_batch_05_0.4_0.44_100")

# %%
validation_collection = TestCollectionV2.load("validation_wSnippets_batch_05_0.4_0.44_100")

# %%
validation_collection.evaluator

# %%
runs = ["8b-b04-bioinfo-2.json"]

evaluator = BioASQ_JavaEvaluator("yearly_data/8B4_golden.json", 
                                 "/home/tiagoalmeida/BioASQ-9b/BioASQEvaluator/BioASQEvaluation.jar")

for r in runs:
    m = evaluator.evaluate(r)
    out = f"{r}:\n\tDoc:\n\t\tMap@10: {m['doc_map@10']}\n\t\tRecall@10: {m['doc_r@10']}"
    if float(m['snippet_r@10'])>0:
        out += f"\n\tSnippet:\n\t\tMap@10: {m['snippet_map@10']}\n\t\tRecall@10: {m['snippet_r@10']}\n\t\tF1@10: {m['snippet_f1@10']}"
    print(out)
# Out:
# Remove /tmp/tmper3ivh24
# 8b-b04-bioinfo-2.json:
# 	Doc:
# 		Map@10: 0.40057199546485267
# 		Recall@10: 0.5552987012987013
# 	Snippet:
# 		Map@10: 0.3658896457209854
# 		Recall@10: 0.2584178478525874
# 		F1@10: 0.17229742697268072

# %%
runs = ["8b-b04-bioinfo-2.json"]

evaluator = BioASQ_JavaEvaluator("yearly_data/8B4_golden.json", 
                                 "/home/tiagoalmeida/BioASQ-9b/BioASQEvaluator/BioASQEvaluation.jar")

for r in runs:
    m = evaluator.evaluate(r)
    out = f"{r}:\n\tDoc:\n\t\tMap@10: {m['doc_map@10']}\n\t\tRecall@10: {m['doc_r@10']}"
    if float(m['snippet_r@10'])>0:
        out += f"\n\tSnippet:\n\t\tMap@10: {m['snippet_map@10']}\n\t\tRecall@10: {m['snippet_r@10']}\n\t\tF1@10: {m['snippet_f1@10']}"
    print(out)
# Out:
# Remove /tmp/tmp5db62sdn
# 8b-b04-bioinfo-2.json:
# 	Doc:
# 		Map@10: 0.48099051555807515
# 		Recall@10: 0.6006318518646105
# 	Snippet:
# 		Map@10: 0.40186301388153983
# 		Recall@10: 0.27501143521870997
# 		F1@10: 0.20362609203479196

# %%
[t/50 for t in range(0,10)]
# Out:
# [0.0, 0.02, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18]

# %%
def build_data_generators(tokenizer, queries_sw=None, docs_sw=None):
    
    def maybe_tokenize(documents):
        if "tokens" not in documents:
            #split = nltk.sent_tokenize(documents["text"])
            documents["tokens"] = tokenizer.texts_to_sequences(map(lambda x: x["text"],documents["snippets"]))
            if docs_sw is not None:
                for tokenized_sentence in documents["tokens"]:
                    tokenized_sentence = [token for token in tokenized_sentence if token not in docs_sw]
    
    def train_generator(data_generator):
        while True:

            # get the batch triplet
            query, pos_docs, pos_label, neg_docs = next(data_generator)

            # tokenization, this can be cached for efficientcy porpuses NOTE!!
            tokenized_query = tokenizer.texts_to_sequences(query)

            if queries_sw is not None:
                for tokens in tokenized_query:
                    tokenized_query = [token for token in tokens if token not in queries_sw] 
            
            saveReturn = True
            
            for batch_index in range(len(pos_docs)):
                
                # tokenizer with cache in [batch_index][tokens]
                maybe_tokenize(pos_docs[batch_index])
                
                # assertion
                if all([ len(sentence)==0  for sentence in pos_docs[batch_index]["tokens"]]):
                    saveReturn = False
                    break # try a new resampling, NOTE THIS IS A EASY FIX PLS REDO THIS!!!!!!!
                          # for obvious reasons
                
                maybe_tokenize(neg_docs[batch_index])
                
            if saveReturn: # this is not true, if the batch is rejected
                yield tokenized_query, pos_docs, pos_label, neg_docs
                
            
    return train_generator, None

def train_generator_for_model(model):

    if "model" in model.savable_config:
        cfg = model.savable_config["model"]
    
    train_gen, test_gen = build_data_generators(model.tokenizer)
    
    pad_tokens = lambda x, max_len, dtype='int32': tf.keras.preprocessing.sequence.pad_sequences(x, 
                                                                                           maxlen=max_len,
                                                                                           dtype=dtype, 
                                                                                           padding='post', 
                                                                                           truncating='post', 
                                                                                           value=0)

    pad_sentences = lambda x, max_lim, dtype='int32': x[:max_lim] + [[]]*(max_lim-len(x))
    
    pad_labels = lambda x, max_lim, dtype='int32': x[:max_lim] + [0]*(max_lim-len(x))
    
    def maybe_padding(document, labels = None):
        if isinstance(document["tokens"], list):
            #overflow prevention
            bounded_doc_passage = min(cfg["max_passages"],len(document["tokens"]))
            document["sentences_mask"] = [True] * bounded_doc_passage + [False] * (cfg["max_passages"]-bounded_doc_passage)
            document["tokens"] = pad_tokens(pad_sentences(document["tokens"], cfg["max_passages"]), cfg["max_p_terms"])
            if labels is not None:
                document["sentences_labels"] = pad_labels(labels, cfg["max_passages"])
            
    def train_generator(data_generator):
 
        for query, pos_docs, pos_label, neg_docs in train_gen(data_generator):
            
            query = pad_tokens(query, cfg["max_q_terms"])
            
            pos_docs_array = []
            pos_snippets_labels = []
            pos_docs_mask_array = []
            neg_docs_array = []
            neg_docs_mask_array = []
            
            # pad docs, use cache here
            for batch_index in range(len(pos_docs)):
                maybe_padding(pos_docs[batch_index], pos_label[batch_index])
                pos_docs_array.append(pos_docs[batch_index]["tokens"])
                pos_snippets_labels.append(pos_docs[batch_index]["sentences_labels"])
                pos_docs_mask_array.append(pos_docs[batch_index]["sentences_mask"])
                maybe_padding(neg_docs[batch_index])
                neg_docs_array.append(neg_docs[batch_index]["tokens"])
                neg_docs_mask_array.append(neg_docs[batch_index]["sentences_mask"])
            
            yield [query, np.array(pos_docs_array), np.array(pos_docs_mask_array), np.array(pos_snippets_labels)], [query, np.array(neg_docs_array), np.array(neg_docs_mask_array)]
            
    return train_generator

model = load_model("trained_models/earthy-glade-11_val_collection0_map@10")
train_input_generator = train_generator_for_model(model)

training_data_used = "joint_training_batch_05_0.6_0.51_250"
train_collection = TrainSnippetsCollectionV2\
                            .load(training_data_used)\
                            .batch_size(32)\
                            .set_transform_inputs_fn(train_input_generator)
# Out:
# DEBUG created tokenizer bioasq_9b_RegexTokenizer
# False False
# [LOAD FROM CACHE] Load embedding matrix from /backup/BioASQ-9b/embeddings/WORD2VEC_embedding_bioasq_9b_gensim_iter_15_freq0_200_Regex_word2vec_bioasq_9b_RegexTokenizer
# Using einsum for mask bq,bps->bpqs and with embedding dim bqe,bpse->bpqs
# [EMBEDDING MATRIX SHAPE] (5322623, 200)

# %%
q, pos_doc, pos_l_snippet, neg_doc = next(train_collection.generator())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-87271044d224> in <module>
# ----> 1 q, pos_doc, pos_l_snippet, neg_doc = next(train_collection.generator())
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
pos_doc
